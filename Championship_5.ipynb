# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 5
TOURNAMENT_TYPE = TournamentTypes.CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Championship #5
# Players participating in this Championship are : ['Abhi', 'Akash', 'Nats', 'Naati', 'Prateek']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 1    Akash    18          23      333.9         7680           78.3
# 4  Prateek    14          23      255.7         5880           60.9
# 2    Naati    12          23      220.0         5060           52.2
# 3     Nats    10          23      181.3         4170           43.5
# 0     Abhi     8          23      153.5         3530           34.8

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 6    Akash  Prateek    11       2          13      360.0           84.6
# 5    Akash     Nats     8       3          11      296.4           72.7
# 3     Abhi  Prateek     6       7          13      205.4           46.2

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
#   Player_x Player_y Player_z  Wins  Losses  TotalGames  AvgPoints  \
# 2     Abhi    Akash  Prateek     4       1           5      376.0
#
#    WinPercentage
# 2           80.0

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 2     Nats            4
# 3    Naati            3
# 1    Akash            3
# 0     Abhi            1
# 4  Prateek            1

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/28 [00:00<?, ?it/s]
#   7%|▋         | 2/28 [00:00<00:01, 17.41it/s]
#  14%|█▍        | 4/28 [00:00<00:01, 16.05it/s]
#  25%|██▌       | 7/28 [00:00<00:01, 18.06it/s]
#  36%|███▌      | 10/28 [00:00<00:01, 16.93it/s]
#  43%|████▎     | 12/28 [00:00<00:00, 16.55it/s]
#  50%|█████     | 14/28 [00:00<00:00, 16.70it/s]
#  57%|█████▋    | 16/28 [00:00<00:00, 15.12it/s]
#  68%|██████▊   | 19/28 [00:01<00:00, 16.52it/s]
#  79%|███████▊  | 22/28 [00:01<00:00, 17.97it/s]
#  86%|████████▌ | 24/28 [00:01<00:00, 16.72it/s]
#  93%|█████████▎| 26/28 [00:01<00:00, 17.16it/s]
# 100%|██████████| 28/28 [00:01<00:00, 17.19it/s]
# Championship #5
# <style type="text/css">
# </style>
# <table id="T_008b8">
#   <thead>
#     <tr>
#       <th id="T_008b8_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_008b8_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_008b8_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_008b8_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_008b8_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_008b8_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_008b8_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_008b8_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_008b8_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_008b8_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_008b8_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_008b8_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_008b8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_008b8_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_008b8_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_008b8_row0_col3" class="data row0 col3" >1092 (+26)</td>
#       <td id="T_008b8_row0_col4" class="data row0 col4" >228</td>
#       <td id="T_008b8_row0_col5" class="data row0 col5" >60</td>
#       <td id="T_008b8_row0_col6" class="data row0 col6" >9</td>
#       <td id="T_008b8_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_008b8_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_008b8_row0_col9" class="data row0 col9" >3</td>
#       <td id="T_008b8_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_008b8_row0_col11" class="data row0 col11" >2</td>
#     </tr>
#     <tr>
#       <td id="T_008b8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_008b8_row1_col1" class="data row1 col1" >▲ 1</td>
#       <td id="T_008b8_row1_col2" class="data row1 col2" >Ani</td>
#       <td id="T_008b8_row1_col3" class="data row1 col3" >1023 (0)</td>
#       <td id="T_008b8_row1_col4" class="data row1 col4" >125</td>
#       <td id="T_008b8_row1_col5" class="data row1 col5" >55</td>
#       <td id="T_008b8_row1_col6" class="data row1 col6" >4</td>
#       <td id="T_008b8_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_008b8_row1_col8" class="data row1 col8" >5</td>
#       <td id="T_008b8_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_008b8_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_008b8_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_008b8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_008b8_row2_col1" class="data row2 col1" >▼ 1</td>
#       <td id="T_008b8_row2_col2" class="data row2 col2" >Abhi</td>
#       <td id="T_008b8_row2_col3" class="data row2 col3" >1014 (-13)</td>
#       <td id="T_008b8_row2_col4" class="data row2 col4" >170</td>
#       <td id="T_008b8_row2_col5" class="data row2 col5" >52</td>
#       <td id="T_008b8_row2_col6" class="data row2 col6" >7</td>
#       <td id="T_008b8_row2_col7" class="data row2 col7" >6</td>
#       <td id="T_008b8_row2_col8" class="data row2 col8" >7</td>
#       <td id="T_008b8_row2_col9" class="data row2 col9" >2</td>
#       <td id="T_008b8_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_008b8_row2_col11" class="data row2 col11" >2</td>
#     </tr>
#     <tr>
#       <td id="T_008b8_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_008b8_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_008b8_row3_col2" class="data row3 col2" >Naati</td>
#       <td id="T_008b8_row3_col3" class="data row3 col3" >1012 (+1)</td>
#       <td id="T_008b8_row3_col4" class="data row3 col4" >228</td>
#       <td id="T_008b8_row3_col5" class="data row3 col5" >51</td>
#       <td id="T_008b8_row3_col6" class="data row3 col6" >10</td>
#       <td id="T_008b8_row3_col7" class="data row3 col7" >9</td>
#       <td id="T_008b8_row3_col8" class="data row3 col8" >5</td>
#       <td id="T_008b8_row3_col9" class="data row3 col9" >4</td>
#       <td id="T_008b8_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_008b8_row3_col11" class="data row3 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_008b8_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_008b8_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_008b8_row4_col2" class="data row4 col2" >Prateek</td>
#       <td id="T_008b8_row4_col3" class="data row4 col3" >1000 (+9)</td>
#       <td id="T_008b8_row4_col4" class="data row4 col4" >228</td>
#       <td id="T_008b8_row4_col5" class="data row4 col5" >50</td>
#       <td id="T_008b8_row4_col6" class="data row4 col6" >7</td>
#       <td id="T_008b8_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_008b8_row4_col8" class="data row4 col8" >5</td>
#       <td id="T_008b8_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_008b8_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_008b8_row4_col11" class="data row4 col11" >2</td>
#     </tr>
#     <tr>
#       <td id="T_008b8_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_008b8_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_008b8_row5_col2" class="data row5 col2" >Nats</td>
#       <td id="T_008b8_row5_col3" class="data row5 col3" >970 (-7)</td>
#       <td id="T_008b8_row5_col4" class="data row5 col4" >161</td>
#       <td id="T_008b8_row5_col5" class="data row5 col5" >44</td>
#       <td id="T_008b8_row5_col6" class="data row5 col6" >5</td>
#       <td id="T_008b8_row5_col7" class="data row5 col7" >6</td>
#       <td id="T_008b8_row5_col8" class="data row5 col8" >9</td>
#       <td id="T_008b8_row5_col9" class="data row5 col9" >4</td>
#       <td id="T_008b8_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_008b8_row5_col11" class="data row5 col11" >4</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
