# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 3
TOURNAMENT_TYPE = TournamentTypes.MINI_CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Mini Championship #3
# Players participating in this Mini Championship are : ['Prateek', 'Ani', 'Abhi', 'Akash']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 0     Abhi    11          18      125.6         2260           61.1
# 1    Akash     9          18      103.9         1870           50.0
# 2      Ani     9          18      100.6         1810           50.0
# 3  Prateek     7          18       79.4         1430           38.9

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Player_z, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 3    Akash            2
# 0  Prateek            1
# 2     Abhi            1
# 1      Ani            0

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/24 [00:00<?, ?it/s]
#   8%|▊         | 2/24 [00:00<00:01, 18.70it/s]
#  17%|█▋        | 4/24 [00:00<00:01, 14.95it/s]
#  25%|██▌       | 6/24 [00:00<00:01, 15.34it/s]
#  33%|███▎      | 8/24 [00:00<00:00, 16.05it/s]
#  42%|████▏     | 10/24 [00:00<00:00, 15.28it/s]
#  50%|█████     | 12/24 [00:00<00:00, 15.87it/s]
#  58%|█████▊    | 14/24 [00:00<00:00, 16.14it/s]
#  67%|██████▋   | 16/24 [00:01<00:00, 15.84it/s]
#  79%|███████▉  | 19/24 [00:01<00:00, 17.15it/s]
#  88%|████████▊ | 21/24 [00:01<00:00, 17.69it/s]
# 100%|██████████| 24/24 [00:01<00:00, 15.82it/s]
# 100%|██████████| 24/24 [00:01<00:00, 16.08it/s]
# Mini Championship #3
# <style type="text/css">
# </style>
# <table id="T_6bef3">
#   <thead>
#     <tr>
#       <th id="T_6bef3_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_6bef3_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_6bef3_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_6bef3_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_6bef3_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_6bef3_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_6bef3_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_6bef3_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_6bef3_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_6bef3_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_6bef3_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_6bef3_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6bef3_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6bef3_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_6bef3_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_6bef3_row0_col3" class="data row0 col3" >1157 (-1)</td>
#       <td id="T_6bef3_row0_col4" class="data row0 col4" >568</td>
#       <td id="T_6bef3_row0_col5" class="data row0 col5" >58</td>
#       <td id="T_6bef3_row0_col6" class="data row0 col6" >12</td>
#       <td id="T_6bef3_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_6bef3_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_6bef3_row0_col9" class="data row0 col9" >14</td>
#       <td id="T_6bef3_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_6bef3_row0_col11" class="data row0 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_6bef3_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6bef3_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_6bef3_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_6bef3_row1_col3" class="data row1 col3" >1034 (-4)</td>
#       <td id="T_6bef3_row1_col4" class="data row1 col4" >568</td>
#       <td id="T_6bef3_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_6bef3_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_6bef3_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_6bef3_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_6bef3_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_6bef3_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_6bef3_row1_col11" class="data row1 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_6bef3_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6bef3_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_6bef3_row2_col2" class="data row2 col2" >Ani</td>
#       <td id="T_6bef3_row2_col3" class="data row2 col3" >1005 (0)</td>
#       <td id="T_6bef3_row2_col4" class="data row2 col4" >283</td>
#       <td id="T_6bef3_row2_col5" class="data row2 col5" >49</td>
#       <td id="T_6bef3_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_6bef3_row2_col7" class="data row2 col7" >8</td>
#       <td id="T_6bef3_row2_col8" class="data row2 col8" >6</td>
#       <td id="T_6bef3_row2_col9" class="data row2 col9" >5</td>
#       <td id="T_6bef3_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_6bef3_row2_col11" class="data row2 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_6bef3_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6bef3_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_6bef3_row3_col2" class="data row3 col2" >Nats</td>
#       <td id="T_6bef3_row3_col3" class="data row3 col3" >1000 (0)</td>
#       <td id="T_6bef3_row3_col4" class="data row3 col4" >483</td>
#       <td id="T_6bef3_row3_col5" class="data row3 col5" >48</td>
#       <td id="T_6bef3_row3_col6" class="data row3 col6" >9</td>
#       <td id="T_6bef3_row3_col7" class="data row3 col7" >10</td>
#       <td id="T_6bef3_row3_col8" class="data row3 col8" >9</td>
#       <td id="T_6bef3_row3_col9" class="data row3 col9" >9</td>
#       <td id="T_6bef3_row3_col10" class="data row3 col10" >1</td>
#       <td id="T_6bef3_row3_col11" class="data row3 col11" >10</td>
#     </tr>
#     <tr>
#       <td id="T_6bef3_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_6bef3_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_6bef3_row4_col2" class="data row4 col2" >Yandigeri</td>
#       <td id="T_6bef3_row4_col3" class="data row4 col3" >999 (0)</td>
#       <td id="T_6bef3_row4_col4" class="data row4 col4" >9</td>
#       <td id="T_6bef3_row4_col5" class="data row4 col5" >44</td>
#       <td id="T_6bef3_row4_col6" class="data row4 col6" >22</td>
#       <td id="T_6bef3_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_6bef3_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_6bef3_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_6bef3_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_6bef3_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6bef3_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_6bef3_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_6bef3_row5_col2" class="data row5 col2" >Naati</td>
#       <td id="T_6bef3_row5_col3" class="data row5 col3" >997 (0)</td>
#       <td id="T_6bef3_row5_col4" class="data row5 col4" >289</td>
#       <td id="T_6bef3_row5_col5" class="data row5 col5" >49</td>
#       <td id="T_6bef3_row5_col6" class="data row5 col6" >8</td>
#       <td id="T_6bef3_row5_col7" class="data row5 col7" >9</td>
#       <td id="T_6bef3_row5_col8" class="data row5 col8" >6</td>
#       <td id="T_6bef3_row5_col9" class="data row5 col9" >5</td>
#       <td id="T_6bef3_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_6bef3_row5_col11" class="data row5 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_6bef3_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_6bef3_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_6bef3_row6_col2" class="data row6 col2" >Abhi</td>
#       <td id="T_6bef3_row6_col3" class="data row6 col3" >949 (+4)</td>
#       <td id="T_6bef3_row6_col4" class="data row6 col4" >493</td>
#       <td id="T_6bef3_row6_col5" class="data row6 col5" >44</td>
#       <td id="T_6bef3_row6_col6" class="data row6 col6" >7</td>
#       <td id="T_6bef3_row6_col7" class="data row6 col7" >6</td>
#       <td id="T_6bef3_row6_col8" class="data row6 col8" >10</td>
#       <td id="T_6bef3_row6_col9" class="data row6 col9" >6</td>
#       <td id="T_6bef3_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_6bef3_row6_col11" class="data row6 col11" >12</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
