# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 4
TOURNAMENT_TYPE = TournamentTypes.TINY_CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Tiny Championship #4
# Players participating in this Tiny Championship are : ['Nats', 'Akash', 'Prateek']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 0    Akash    23          36      133.9         4820           63.9
# 2  Prateek    22          36      124.6         4485           61.1
# 1     Nats    14          36       82.5         2970           38.9

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 1    Akash  Prateek    10       1          11      176.8           90.9
# 0    Akash     Nats     8       7          15      107.0           53.3
# 2     Nats  Prateek     5       5          10      109.0           50.0

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Player_z, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 1    Akash           11
# 0     Nats            4
# 2  Prateek            1

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/24 [00:00<?, ?it/s]
#   4%|▍         | 1/24 [00:00<00:05,  4.01it/s]
#   8%|▊         | 2/24 [00:00<00:03,  5.90it/s]
#  12%|█▎        | 3/24 [00:00<00:03,  5.59it/s]
#  17%|█▋        | 4/24 [00:00<00:03,  5.22it/s]
#  25%|██▌       | 6/24 [00:00<00:02,  7.21it/s]
#  29%|██▉       | 7/24 [00:01<00:02,  7.44it/s]
#  33%|███▎      | 8/24 [00:01<00:02,  7.36it/s]
#  38%|███▊      | 9/24 [00:01<00:02,  6.89it/s]
#  42%|████▏     | 10/24 [00:01<00:03,  3.63it/s]
#  46%|████▌     | 11/24 [00:02<00:03,  3.39it/s]
#  50%|█████     | 12/24 [00:02<00:02,  4.02it/s]
#  54%|█████▍    | 13/24 [00:02<00:02,  4.29it/s]
#  58%|█████▊    | 14/24 [00:02<00:02,  4.24it/s]
#  62%|██████▎   | 15/24 [00:03<00:02,  4.14it/s]
#  71%|███████   | 17/24 [00:03<00:01,  6.42it/s]
#  79%|███████▉  | 19/24 [00:03<00:00,  8.68it/s]
#  92%|█████████▏| 22/24 [00:03<00:00, 11.92it/s]
# 100%|██████████| 24/24 [00:03<00:00, 12.45it/s]
# 100%|██████████| 24/24 [00:03<00:00,  6.58it/s]
# Tiny Championship #4
# <style type="text/css">
# </style>
# <table id="T_abbbd">
#   <thead>
#     <tr>
#       <th id="T_abbbd_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_abbbd_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_abbbd_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_abbbd_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_abbbd_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_abbbd_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_abbbd_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_abbbd_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_abbbd_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_abbbd_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_abbbd_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_abbbd_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_abbbd_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_abbbd_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_abbbd_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_abbbd_row0_col3" class="data row0 col3" >1191 (+4)</td>
#       <td id="T_abbbd_row0_col4" class="data row0 col4" >876</td>
#       <td id="T_abbbd_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_abbbd_row0_col6" class="data row0 col6" >14</td>
#       <td id="T_abbbd_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_abbbd_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_abbbd_row0_col9" class="data row0 col9" >22</td>
#       <td id="T_abbbd_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_abbbd_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_abbbd_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_abbbd_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_abbbd_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_abbbd_row1_col3" class="data row1 col3" >1048 (+6)</td>
#       <td id="T_abbbd_row1_col4" class="data row1 col4" >707</td>
#       <td id="T_abbbd_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_abbbd_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_abbbd_row1_col7" class="data row1 col7" >9</td>
#       <td id="T_abbbd_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_abbbd_row1_col9" class="data row1 col9" >7</td>
#       <td id="T_abbbd_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_abbbd_row1_col11" class="data row1 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_abbbd_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_abbbd_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_abbbd_row2_col2" class="data row2 col2" >Nats</td>
#       <td id="T_abbbd_row2_col3" class="data row2 col3" >1026 (-5)</td>
#       <td id="T_abbbd_row2_col4" class="data row2 col4" >791</td>
#       <td id="T_abbbd_row2_col5" class="data row2 col5" >49</td>
#       <td id="T_abbbd_row2_col6" class="data row2 col6" >12</td>
#       <td id="T_abbbd_row2_col7" class="data row2 col7" >10</td>
#       <td id="T_abbbd_row2_col8" class="data row2 col8" >9</td>
#       <td id="T_abbbd_row2_col9" class="data row2 col9" >15</td>
#       <td id="T_abbbd_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_abbbd_row2_col11" class="data row2 col11" >15</td>
#     </tr>
#     <tr>
#       <td id="T_abbbd_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_abbbd_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_abbbd_row3_col2" class="data row3 col2" >Ani</td>
#       <td id="T_abbbd_row3_col3" class="data row3 col3" >1005 (0)</td>
#       <td id="T_abbbd_row3_col4" class="data row3 col4" >283</td>
#       <td id="T_abbbd_row3_col5" class="data row3 col5" >49</td>
#       <td id="T_abbbd_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_abbbd_row3_col7" class="data row3 col7" >8</td>
#       <td id="T_abbbd_row3_col8" class="data row3 col8" >6</td>
#       <td id="T_abbbd_row3_col9" class="data row3 col9" >5</td>
#       <td id="T_abbbd_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_abbbd_row3_col11" class="data row3 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_abbbd_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_abbbd_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_abbbd_row4_col2" class="data row4 col2" >Shreyas</td>
#       <td id="T_abbbd_row4_col3" class="data row4 col3" >1000 (0)</td>
#       <td id="T_abbbd_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_abbbd_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_abbbd_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_abbbd_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_abbbd_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_abbbd_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_abbbd_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_abbbd_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_abbbd_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_abbbd_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_abbbd_row5_col2" class="data row5 col2" >Skanda</td>
#       <td id="T_abbbd_row5_col3" class="data row5 col3" >1000 (0)</td>
#       <td id="T_abbbd_row5_col4" class="data row5 col4" >172</td>
#       <td id="T_abbbd_row5_col5" class="data row5 col5" >46</td>
#       <td id="T_abbbd_row5_col6" class="data row5 col6" >13</td>
#       <td id="T_abbbd_row5_col7" class="data row5 col7" >5</td>
#       <td id="T_abbbd_row5_col8" class="data row5 col8" >6</td>
#       <td id="T_abbbd_row5_col9" class="data row5 col9" >2</td>
#       <td id="T_abbbd_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_abbbd_row5_col11" class="data row5 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_abbbd_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_abbbd_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_abbbd_row6_col2" class="data row6 col2" >Yandigeri</td>
#       <td id="T_abbbd_row6_col3" class="data row6 col3" >999 (0)</td>
#       <td id="T_abbbd_row6_col4" class="data row6 col4" >9</td>
#       <td id="T_abbbd_row6_col5" class="data row6 col5" >44</td>
#       <td id="T_abbbd_row6_col6" class="data row6 col6" >22</td>
#       <td id="T_abbbd_row6_col7" class="data row6 col7" >3</td>
#       <td id="T_abbbd_row6_col8" class="data row6 col8" >3</td>
#       <td id="T_abbbd_row6_col9" class="data row6 col9" >0</td>
#       <td id="T_abbbd_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_abbbd_row6_col11" class="data row6 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_abbbd_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_abbbd_row7_col1" class="data row7 col1" >-</td>
#       <td id="T_abbbd_row7_col2" class="data row7 col2" >Naati</td>
#       <td id="T_abbbd_row7_col3" class="data row7 col3" >997 (0)</td>
#       <td id="T_abbbd_row7_col4" class="data row7 col4" >289</td>
#       <td id="T_abbbd_row7_col5" class="data row7 col5" >49</td>
#       <td id="T_abbbd_row7_col6" class="data row7 col6" >8</td>
#       <td id="T_abbbd_row7_col7" class="data row7 col7" >9</td>
#       <td id="T_abbbd_row7_col8" class="data row7 col8" >6</td>
#       <td id="T_abbbd_row7_col9" class="data row7 col9" >5</td>
#       <td id="T_abbbd_row7_col10" class="data row7 col10" >0</td>
#       <td id="T_abbbd_row7_col11" class="data row7 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_abbbd_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_abbbd_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_abbbd_row8_col2" class="data row8 col2" >Darshan</td>
#       <td id="T_abbbd_row8_col3" class="data row8 col3" >997 (0)</td>
#       <td id="T_abbbd_row8_col4" class="data row8 col4" >61</td>
#       <td id="T_abbbd_row8_col5" class="data row8 col5" >47</td>
#       <td id="T_abbbd_row8_col6" class="data row8 col6"
#  -----------------------------

# %% [markdown]
# ### Fin!
