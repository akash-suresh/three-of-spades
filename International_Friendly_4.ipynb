# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 4
TOURNAMENT_TYPE = TournamentTypes.FRIENDLY
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades International Friendly #4
# Players participating in this International Friendly are : ['Naati', 'Skanda', 'Nats', 'Abhi', 'Akash']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#    Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 4  Skanda     7           9      288.9         2600           77.8
# 1   Akash     6           9      261.1         2350           66.7
# 3    Nats     4           9      176.7         1590           44.4
# 2   Naati     3           9      121.1         1090           33.3
# 0    Abhi     2           9       94.4          850           22.2

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Player_z, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#    Player  Bid and Won
# 4   Akash            1
# 0   Naati            0
# 1  Skanda            0
# 2    Nats            0
# 3    Abhi            0

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/28 [00:00<?, ?it/s]
#   7%|▋         | 2/28 [00:00<00:01, 17.99it/s]
#  14%|█▍        | 4/28 [00:00<00:01, 16.32it/s]
#  25%|██▌       | 7/28 [00:00<00:01, 18.22it/s]
#  36%|███▌      | 10/28 [00:00<00:01, 17.09it/s]
#  43%|████▎     | 12/28 [00:00<00:01, 14.72it/s]
#  50%|█████     | 14/28 [00:01<00:01, 10.36it/s]
#  57%|█████▋    | 16/28 [00:01<00:01, 10.08it/s]
#  64%|██████▍   | 18/28 [00:01<00:00, 11.78it/s]
#  71%|███████▏  | 20/28 [00:01<00:00, 13.12it/s]
#  82%|████████▏ | 23/28 [00:01<00:00, 15.50it/s]
#  89%|████████▉ | 25/28 [00:01<00:00, 14.97it/s]
#  96%|█████████▋| 27/28 [00:01<00:00, 16.08it/s]
# 100%|██████████| 28/28 [00:01<00:00, 14.42it/s]
# International Friendly #4
# <style type="text/css">
# </style>
# <table id="T_6c946">
#   <thead>
#     <tr>
#       <th id="T_6c946_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_6c946_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_6c946_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_6c946_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_6c946_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_6c946_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_6c946_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_6c946_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_6c946_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_6c946_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_6c946_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_6c946_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6c946_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6c946_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_6c946_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_6c946_row0_col3" class="data row0 col3" >1205 (+4)</td>
#       <td id="T_6c946_row0_col4" class="data row0 col4" >1323</td>
#       <td id="T_6c946_row0_col5" class="data row0 col5" >57</td>
#       <td id="T_6c946_row0_col6" class="data row0 col6" >13</td>
#       <td id="T_6c946_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_6c946_row0_col8" class="data row0 col8" >9</td>
#       <td id="T_6c946_row0_col9" class="data row0 col9" >34</td>
#       <td id="T_6c946_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_6c946_row0_col11" class="data row0 col11" >11</td>
#     </tr>
#     <tr>
#       <td id="T_6c946_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6c946_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_6c946_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_6c946_row1_col3" class="data row1 col3" >1081 (0)</td>
#       <td id="T_6c946_row1_col4" class="data row1 col4" >1047</td>
#       <td id="T_6c946_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_6c946_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_6c946_row1_col7" class="data row1 col7" >9</td>
#       <td id="T_6c946_row1_col8" class="data row1 col8" >7</td>
#       <td id="T_6c946_row1_col9" class="data row1 col9" >15</td>
#       <td id="T_6c946_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_6c946_row1_col11" class="data row1 col11" >9</td>
#     </tr>
#     <tr>
#       <td id="T_6c946_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6c946_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_6c946_row2_col2" class="data row2 col2" >Nats</td>
#       <td id="T_6c946_row2_col3" class="data row2 col3" >1033 (-1)</td>
#       <td id="T_6c946_row2_col4" class="data row2 col4" >1238</td>
#       <td id="T_6c946_row2_col5" class="data row2 col5" >48</td>
#       <td id="T_6c946_row2_col6" class="data row2 col6" >13</td>
#       <td id="T_6c946_row2_col7" class="data row2 col7" >10</td>
#       <td id="T_6c946_row2_col8" class="data row2 col8" >10</td>
#       <td id="T_6c946_row2_col9" class="data row2 col9" >21</td>
#       <td id="T_6c946_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_6c946_row2_col11" class="data row2 col11" >23</td>
#     </tr>
#     <tr>
#       <td id="T_6c946_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6c946_row3_col1" class="data row3 col1" >▲ 1</td>
#       <td id="T_6c946_row3_col2" class="data row3 col2" >Skanda</td>
#       <td id="T_6c946_row3_col3" class="data row3 col3" >1009 (+8)</td>
#       <td id="T_6c946_row3_col4" class="data row3 col4" >267</td>
#       <td id="T_6c946_row3_col5" class="data row3 col5" >47</td>
#       <td id="T_6c946_row3_col6" class="data row3 col6" >11</td>
#       <td id="T_6c946_row3_col7" class="data row3 col7" >6</td>
#       <td id="T_6c946_row3_col8" class="data row3 col8" >7</td>
#       <td id="T_6c946_row3_col9" class="data row3 col9" >5</td>
#       <td id="T_6c946_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_6c946_row3_col11" class="data row3 col11" >8</td>
#     </tr>
#     <tr>
#       <td id="T_6c946_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_6c946_row4_col1" class="data row4 col1" >▼ 1</td>
#       <td id="T_6c946_row4_col2" class="data row4 col2" >Shreyas</td>
#       <td id="T_6c946_row4_col3" class="data row4 col3" >1000 (0)</td>
#       <td id="T_6c946_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_6c946_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_6c946_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_6c946_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_6c946_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_6c946_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_6c946_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_6c946_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6c946_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_6c946_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_6c946_row5_col2" class="data row5 col2" >Yandigeri</td>
#       <td id="T_6c946_row5_col3" class="data row5 col3" >999 (0)</td>
#       <td id="T_6c946_row5_col4" class="data row5 col4" >9</td>
#       <td id="T_6c946_row5_col5" class="data row5 col5" >44</td>
#       <td id="T_6c946_row5_col6" class="data row5 col6" >22</td>
#       <td id="T_6c946_row5_col7" class="data row5 col7" >3</td>
#       <td id="T_6c946_row5_col8" class="data row5 col8" >3</td>
#       <td id="T_6c946_row5_col9" class="data row5 col9" >0</td>
#       <td id="T_6c946_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_6c946_row5_col11" class="data row5 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6c946_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_6c946_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_6c946_row6_col2" class="data row6 col2" >Chirag</td>
#       <td id="T_6c946_row6_col3" class="data row6 col3" >999 (0)</td>
#       <td id="T_6c946_row6_col4" class="data row6 col4" >27</td>
#       <td id="T_6c946_row6_col5" class="data row6 col5" >48</td>
#       <td id="T_6c946_row6_col6" class="data row6 col6" >3</td>
#       <td id="T_6c946_row6_col7" class="data row6 col7" >4</td>
#       <td id="T_6c946_row6_col8" class="data row6 col8" >4</td>
#       <td id="T_6c946_row6_col9" class="data row6 col9" >0</td>
#       <td id="T_6c946_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_6c946_row6_col11" class="data row6 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6c946_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_6c946_row7_col1" class="data row7 col1" >-</td>
#       <td id="T_6c946_row7_col2" class="data row7 col2" >Ani</td>
#       <td id="T_6c946_row7_col3" class="data row7 col3" >999 (0)</td>
#       <td id="T_6c946_row7_col4" class="data row7 col4" >358</td>
#       <td id="T_6c946_row7_col5" class="data row7 col5" >48</td>
#       <td id="T_6c946_row7_col6" class="data row7 col6" >3</td>
#       <td id="T_6c946_row7_col7" class="data row7 col7" >8</td>
#       <td id="T_6c946_row7_col8" class="data row7 col8" >7</td>
#       <td id="T_6c946_row7_col9" class="data row7 col9" >5</td>
#       <td id="T_6c946_row7_col10" class="data row7 col10" >0</td>
#       <td id="T_6c946_row7_col11" class="data row7 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_6c946_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_6c946_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_6c946_row8_col2" class="data row8 col2" >Darshan</td>
#       <td id="T_6c946_row8_col3" class="data row8 col3" >997 (0)</td>
#       <td id="T_6c946_row8_col4" class="data row8 col4" >61</td>
#       <td id="T_6c946_row8_col5" class="data row8 col5" >47</td>
#       <td id="T_6c946_row8_col6" class="data
#  -----------------------------

# %% [markdown]
# ### Fin!
