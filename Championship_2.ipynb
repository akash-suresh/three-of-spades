# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 2
TOURNAMENT_TYPE = TournamentTypes.CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Championship #2
# Players participating in this Championship are : ['Ani', 'Abhi', 'Akash', 'Naati', 'Prateek']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 1    Akash    20          30      255.7         7670           66.7
# 2      Ani    19          30      242.0         7260           63.3
# 0     Abhi    16          30      205.7         6170           53.3
# 3    Naati    13          30      168.0         5040           43.3
# 4  Prateek    11          30      137.3         4120           36.7

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 4    Akash      Ani    11       2          13      325.4           84.6
# 1     Abhi      Ani    10       5          15      254.0           66.7
# 5    Akash    Naati     7       4          11      235.5           63.6
# 7      Ani    Naati     7       5          12      228.3           58.3
# 6    Akash  Prateek     8       7          15      192.0           53.3
# 2     Abhi    Naati     7       8          15      180.7           46.7
# 3     Abhi  Prateek     4       7          11      130.9           36.4
# 9    Naati  Prateek     3       9          12       96.7           25.0

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
#   Player_x Player_y Player_z  Wins  Losses  TotalGames  AvgPoints  \
# 3     Abhi      Ani    Naati     4       2           6      268.3
#
#    WinPercentage
# 3           66.7

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 1     Abhi            4
# 4  Prateek            3
# 2    Akash            2
# 3    Naati            2
# 0      Ani            0

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/28 [00:00<?, ?it/s]
#   7%|▋         | 2/28 [00:00<00:01, 14.49it/s]
#  14%|█▍        | 4/28 [00:00<00:02, 11.54it/s]
#  21%|██▏       | 6/28 [00:00<00:01, 13.81it/s]
#  29%|██▊       | 8/28 [00:00<00:01, 15.06it/s]
#  36%|███▌      | 10/28 [00:00<00:01, 14.70it/s]
#  43%|████▎     | 12/28 [00:00<00:01, 15.12it/s]
#  50%|█████     | 14/28 [00:00<00:00, 14.56it/s]
#  57%|█████▋    | 16/28 [00:01<00:00, 14.85it/s]
#  64%|██████▍   | 18/28 [00:01<00:00, 15.71it/s]
#  71%|███████▏  | 20/28 [00:01<00:00, 16.24it/s]
#  82%|████████▏ | 23/28 [00:01<00:00, 18.00it/s]
#  89%|████████▉ | 25/28 [00:01<00:00, 16.66it/s]
#  96%|█████████▋| 27/28 [00:01<00:00, 17.46it/s]
# 100%|██████████| 28/28 [00:01<00:00, 15.94it/s]
# Championship #2
# <style type="text/css">
# </style>
# <table id="T_93627">
#   <thead>
#     <tr>
#       <th id="T_93627_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_93627_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_93627_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_93627_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_93627_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_93627_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_93627_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_93627_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_93627_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_93627_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_93627_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_93627_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_93627_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_93627_row0_col1" class="data row0 col1" >▲ 1</td>
#       <td id="T_93627_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_93627_row0_col3" class="data row0 col3" >1027 (+18)</td>
#       <td id="T_93627_row0_col4" class="data row0 col4" >67</td>
#       <td id="T_93627_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_93627_row0_col6" class="data row0 col6" >8</td>
#       <td id="T_93627_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_93627_row0_col8" class="data row0 col8" >4</td>
#       <td id="T_93627_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_93627_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_93627_row0_col11" class="data row0 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_93627_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_93627_row1_col1" class="data row1 col1" >▲ 3</td>
#       <td id="T_93627_row1_col2" class="data row1 col2" >Ani</td>
#       <td id="T_93627_row1_col3" class="data row1 col3" >1013 (+15)</td>
#       <td id="T_93627_row1_col4" class="data row1 col4" >67</td>
#       <td id="T_93627_row1_col5" class="data row1 col5" >55</td>
#       <td id="T_93627_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_93627_row1_col7" class="data row1 col7" >6</td>
#       <td id="T_93627_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_93627_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_93627_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_93627_row1_col11" class="data row1 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_93627_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_93627_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_93627_row2_col2" class="data row2 col2" >Abhi</td>
#       <td id="T_93627_row2_col3" class="data row2 col3" >1011 (+3)</td>
#       <td id="T_93627_row2_col4" class="data row2 col4" >67</td>
#       <td id="T_93627_row2_col5" class="data row2 col5" >55</td>
#       <td id="T_93627_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_93627_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_93627_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_93627_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_93627_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_93627_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_93627_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_93627_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_93627_row3_col2" class="data row3 col2" >Naati</td>
#       <td id="T_93627_row3_col3" class="data row3 col3" >1000 (-7)</td>
#       <td id="T_93627_row3_col4" class="data row3 col4" >67</td>
#       <td id="T_93627_row3_col5" class="data row3 col5" >49</td>
#       <td id="T_93627_row3_col6" class="data row3 col6" >10</td>
#       <td id="T_93627_row3_col7" class="data row3 col7" >4</td>
#       <td id="T_93627_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_93627_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_93627_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_93627_row3_col11" class="data row3 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_93627_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_93627_row4_col1" class="data row4 col1" >▼ 4</td>
#       <td id="T_93627_row4_col2" class="data row4 col2" >Prateek</td>
#       <td id="T_93627_row4_col3" class="data row4 col3" >995 (-16)</td>
#       <td id="T_93627_row4_col4" class="data row4 col4" >67</td>
#       <td id="T_93627_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_93627_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_93627_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_93627_row4_col8" class="data row4 col8" >5</td>
#       <td id="T_93627_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_93627_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_93627_row4_col11" class="data row4 col11" >1</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
