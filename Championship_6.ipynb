# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 6
TOURNAMENT_TYPE = TournamentTypes.CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Championship #6
# Players participating in this Championship are : ['Abhi', 'Akash', 'Ani', 'Naati', 'Nats', 'Prateek']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 1    Akash    31          44      286.1        12590           70.5
# 5  Prateek    29          44      260.2        11450           65.9
# 4     Nats    24          44      220.5         9700           54.5
# 0     Abhi    19          44      173.0         7610           43.2
# 3    Naati    19          44      170.7         7510           43.2
# 2      Ani    17          44      156.6         6890           38.6

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#    Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 8     Akash  Prateek    18       2          20      354.5           90.0
# 14     Nats  Prateek    13       4          17      300.0           76.5
# 7     Akash     Nats    16       5          21      309.5           76.2
# 0      Abhi    Akash    12       6          18      271.1           66.7
# 6     Akash    Naati    13       7          20      255.5           65.0
# 4      Abhi  Prateek     9       5          14      250.7           64.3
# 5     Akash      Ani    10       6          16      258.8           62.5
# 13    Naati  Prateek    14      10          24      228.8           58.3
# 11      Ani  Prateek     9       7          16      218.8           56.2
# 3      Abhi     Nats     9      10          19      188.9           47.4
# 12    Naati     Nats     6       7          13      183.8           46.2
# 10      Ani     Nats    10      13          23      177.4           43.5
# 1      Abhi      Ani     7      15          22      128.6           31.8
# 2      Abhi    Naati     4      10          14      113.6           28.6
# 9       Ani    Naati     3      11          14       85.0           21.4

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
#    Player_x Player_y Player_z  Wins  Losses  TotalGames  AvgPoints  \
# 15    Akash     Nats  Prateek     7       0           7      394.3
# 14    Akash    Naati  Prateek     9       1          10      352.0
# 11    Akash      Ani     Nats     7       1           8      362.5
# 2      Abhi    Akash     Nats     6       1           7      348.6
# 19    Naati     Nats  Prateek     4       1           5      318.0
# 18      Ani     Nats  Prateek     4       2           6      258.3
# 0      Abhi    Akash      Ani     3       3           6      211.7
# 13    Akash    Naati     Nats     2       3           5      156.0
# 5      Abhi      Ani     Nats     2       8          10       82.0
# 17      Ani    Naati  Prateek     1       4           5       76.0
#
#     WinPercentage
# 15          100.0
# 14           90.0
# 11           87.5
# 2            85.7
# 19           80.0
# 18           66.7
# 0            50.0
# 13           40.0
# 5            20.0
# 17           20.0

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 1    Akash            6
# 5  Prateek            4
# 4     Nats            3
# 0     Abhi            1
# 2      Ani            1
# 3    Naati            1

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/13 [00:00<?, ?it/s]
#  15%|█▌        | 2/13 [00:00<00:00, 13.03it/s]
#  31%|███       | 4/13 [00:00<00:00, 10.75it/s]
#  46%|████▌     | 6/13 [00:00<00:00, 11.71it/s]
#  62%|██████▏   | 8/13 [00:00<00:00, 11.75it/s]
#  77%|███████▋  | 10/13 [00:00<00:00, 11.09it/s]
#  92%|█████████▏| 12/13 [00:01<00:00, 12.18it/s]
# 100%|██████████| 13/13 [00:01<00:00, 12.02it/s]
# Championship #6
# <style type="text/css">
# </style>
# <table id="T_ba6d4">
#   <thead>
#     <tr>
#       <th id="T_ba6d4_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_ba6d4_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_ba6d4_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_ba6d4_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_ba6d4_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_ba6d4_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_ba6d4_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ba6d4_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ba6d4_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_ba6d4_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_ba6d4_row0_col3" class="data row0 col3" >1128 (+34)</td>
#       <td id="T_ba6d4_row0_col4" class="data row0 col4" >289</td>
#       <td id="T_ba6d4_row0_col5" class="data row0 col5" >61</td>
#       <td id="T_ba6d4_row0_col6" class="data row0 col6" >11</td>
#     </tr>
#     <tr>
#       <td id="T_ba6d4_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ba6d4_row1_col1" class="data row1 col1" >▲ 3</td>
#       <td id="T_ba6d4_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_ba6d4_row1_col3" class="data row1 col3" >1030 (+25)</td>
#       <td id="T_ba6d4_row1_col4" class="data row1 col4" >289</td>
#       <td id="T_ba6d4_row1_col5" class="data row1 col5" >52</td>
#       <td id="T_ba6d4_row1_col6" class="data row1 col6" >7</td>
#     </tr>
#     <tr>
#       <td id="T_ba6d4_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ba6d4_row2_col1" class="data row2 col1" >▼ 1</td>
#       <td id="T_ba6d4_row2_col2" class="data row2 col2" >Ani</td>
#       <td id="T_ba6d4_row2_col3" class="data row2 col3" >1005 (-18)</td>
#       <td id="T_ba6d4_row2_col4" class="data row2 col4" >169</td>
#       <td id="T_ba6d4_row2_col5" class="data row2 col5" >50</td>
#       <td id="T_ba6d4_row2_col6" class="data row2 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_ba6d4_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ba6d4_row3_col1" class="data row3 col1" >▼ 1</td>
#       <td id="T_ba6d4_row3_col2" class="data row3 col2" >Abhi</td>
#       <td id="T_ba6d4_row3_col3" class="data row3 col3" >1002 (-12)</td>
#       <td id="T_ba6d4_row3_col4" class="data row3 col4" >214</td>
#       <td id="T_ba6d4_row3_col5" class="data row3 col5" >50</td>
#       <td id="T_ba6d4_row3_col6" class="data row3 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_ba6d4_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ba6d4_row4_col1" class="data row4 col1" >▼ 1</td>
#       <td id="T_ba6d4_row4_col2" class="data row4 col2" >Naati</td>
#       <td id="T_ba6d4_row4_col3" class="data row4 col3" >996 (-13)</td>
#       <td id="T_ba6d4_row4_col4" class="data row4 col4" >289</td>
#       <td id="T_ba6d4_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_ba6d4_row4_col6" class="data row4 col6" >8</td>
#     </tr>
#     <tr>
#       <td id="T_ba6d4_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_ba6d4_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_ba6d4_row5_col2" class="data row5 col2" >Nats</td>
#       <td id="T_ba6d4_row5_col3" class="data row5 col3" >980 (+9)</td>
#       <td id="T_ba6d4_row5_col4" class="data row5 col4" >222</td>
#       <td id="T_ba6d4_row5_col5" class="data row5 col5" >46</td>
#       <td id="T_ba6d4_row5_col6" class="data row5 col6" >7</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
