# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 2
TOURNAMENT_TYPE = TournamentTypes.MINI_CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Mini Championship #2
# Players participating in this Mini Championship are : ['Abhi', 'Akash', 'Prateek', 'Nats']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 3  Prateek    93         156      125.1        19510           59.6
# 1    Akash    86         156      114.3        17835           55.1
# 2     Nats    77         156      104.7        16340           49.4
# 0     Abhi    56         156       74.2        11575           35.9

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 4    Akash  Prateek    34      11          45      153.1           75.6
# 5     Nats  Prateek    39      25          64      126.8           60.9
# 3    Akash     Nats    27      20          47      116.2           57.4
# 2     Abhi  Prateek    20      27          47       86.1           42.6
# 0     Abhi    Akash    25      39          64       78.5           39.1
# 1     Abhi     Nats    11      34          45       50.3           24.4

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Player_z, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 3     Nats           25
# 1    Akash           23
# 2  Prateek           23
# 0     Abhi           12

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/28 [00:00<?, ?it/s]
#   7%|▋         | 2/28 [00:00<00:01, 16.42it/s]
#  14%|█▍        | 4/28 [00:00<00:01, 15.15it/s]
#  21%|██▏       | 6/28 [00:00<00:01, 17.00it/s]
#  29%|██▊       | 8/28 [00:00<00:01, 16.87it/s]
#  36%|███▌      | 10/28 [00:00<00:01, 15.81it/s]
#  43%|████▎     | 12/28 [00:00<00:00, 16.76it/s]
#  50%|█████     | 14/28 [00:00<00:00, 15.41it/s]
#  57%|█████▋    | 16/28 [00:01<00:00, 14.43it/s]
#  68%|██████▊   | 19/28 [00:01<00:00, 14.79it/s]
#  79%|███████▊  | 22/28 [00:01<00:00, 16.68it/s]
#  86%|████████▌ | 24/28 [00:01<00:00, 15.01it/s]
#  93%|█████████▎| 26/28 [00:01<00:00, 15.86it/s]
# 100%|██████████| 28/28 [00:01<00:00, 16.12it/s]
# Mini Championship #2
# <style type="text/css">
# </style>
# <table id="T_593de">
#   <thead>
#     <tr>
#       <th id="T_593de_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_593de_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_593de_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_593de_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_593de_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_593de_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_593de_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_593de_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_593de_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_593de_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_593de_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_593de_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_593de_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_593de_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_593de_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_593de_row0_col3" class="data row0 col3" >1155 (+3)</td>
#       <td id="T_593de_row0_col4" class="data row0 col4" >491</td>
#       <td id="T_593de_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_593de_row0_col6" class="data row0 col6" >12</td>
#       <td id="T_593de_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_593de_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_593de_row0_col9" class="data row0 col9" >13</td>
#       <td id="T_593de_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_593de_row0_col11" class="data row0 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_593de_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_593de_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_593de_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_593de_row1_col3" class="data row1 col3" >1056 (+25)</td>
#       <td id="T_593de_row1_col4" class="data row1 col4" >491</td>
#       <td id="T_593de_row1_col5" class="data row1 col5" >54</td>
#       <td id="T_593de_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_593de_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_593de_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_593de_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_593de_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_593de_row1_col11" class="data row1 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_593de_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_593de_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_593de_row2_col2" class="data row2 col2" >Yandigeri</td>
#       <td id="T_593de_row2_col3" class="data row2 col3" >999 (0)</td>
#       <td id="T_593de_row2_col4" class="data row2 col4" >9</td>
#       <td id="T_593de_row2_col5" class="data row2 col5" >44</td>
#       <td id="T_593de_row2_col6" class="data row2 col6" >22</td>
#       <td id="T_593de_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_593de_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_593de_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_593de_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_593de_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_593de_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_593de_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_593de_row3_col2" class="data row3 col2" >Ani</td>
#       <td id="T_593de_row3_col3" class="data row3 col3" >997 (0)</td>
#       <td id="T_593de_row3_col4" class="data row3 col4" >206</td>
#       <td id="T_593de_row3_col5" class="data row3 col5" >49</td>
#       <td id="T_593de_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_593de_row3_col7" class="data row3 col7" >8</td>
#       <td id="T_593de_row3_col8" class="data row3 col8" >6</td>
#       <td id="T_593de_row3_col9" class="data row3 col9" >4</td>
#       <td id="T_593de_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_593de_row3_col11" class="data row3 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_593de_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_593de_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_593de_row4_col2" class="data row4 col2" >Naati</td>
#       <td id="T_593de_row4_col3" class="data row4 col3" >997 (0)</td>
#       <td id="T_593de_row4_col4" class="data row4 col4" >289</td>
#       <td id="T_593de_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_593de_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_593de_row4_col7" class="data row4 col7" >9</td>
#       <td id="T_593de_row4_col8" class="data row4 col8" >6</td>
#       <td id="T_593de_row4_col9" class="data row4 col9" >5</td>
#       <td id="T_593de_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_593de_row4_col11" class="data row4 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_593de_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_593de_row5_col1" class="data row5 col1" >▲ 1</td>
#       <td id="T_593de_row5_col2" class="data row5 col2" >Nats</td>
#       <td id="T_593de_row5_col3" class="data row5 col3" >983 (+5)</td>
#       <td id="T_593de_row5_col4" class="data row5 col4" >424</td>
#       <td id="T_593de_row5_col5" class="data row5 col5" >47</td>
#       <td id="T_593de_row5_col6" class="data row5 col6" >10</td>
#       <td id="T_593de_row5_col7" class="data row5 col7" >8</td>
#       <td id="T_593de_row5_col8" class="data row5 col8" >9</td>
#       <td id="T_593de_row5_col9" class="data row5 col9" >8</td>
#       <td id="T_593de_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_593de_row5_col11" class="data row5 col11" >9</td>
#     </tr>
#     <tr>
#       <td id="T_593de_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_593de_row6_col1" class="data row6 col1" >▼ 1</td>
#       <td id="T_593de_row6_col2" class="data row6 col2" >Abhi</td>
#       <td id="T_593de_row6_col3" class="data row6 col3" >957 (-30)</td>
#       <td id="T_593de_row6_col4" class="data row6 col4" >416</td>
#       <td id="T_593de_row6_col5" class="data row6 col5" >44</td>
#       <td id="T_593de_row6_col6" class="data row6 col6" >6</td>
#       <td id="T_593de_row6_col7" class="data row6 col7" >6</td>
#       <td id="T_593de_row6_col8" class="data row6 col8" >10</td>
#       <td id="T_593de_row6_col9" class="data row6 col9" >5</td>
#       <td id="T_593de_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_593de_row6_col11" class="data row6 col11" >9</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
