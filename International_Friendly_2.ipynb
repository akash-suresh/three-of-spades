# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 2
TOURNAMENT_TYPE = TournamentTypes.FRIENDLY
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades International Friendly #2
# Players participating in this International Friendly are : ['Nats', 'Priya', 'Shreyas', 'Darshan', 'Akash']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 0    Akash    35          61      238.4        14540           57.4
# 2     Nats    32          61      219.3        13380           52.5
# 4  Shreyas    30          61      204.4        12470           49.2
# 1  Darshan    29          61      197.4        12040           47.5
# 3    Priya    26          61      179.8        10970           42.6

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 1    Akash     Nats    16      10          26      254.2           61.5
# 0    Akash  Darshan     9       6          15      245.3           60.0
# 3    Akash  Shreyas    14      10          24      238.8           58.3
# 8     Nats  Shreyas    14      13          27      212.2           51.9
# 4  Darshan     Nats    12      12          24      207.9           50.0
# 2    Akash    Priya    15      15          30      210.0           50.0
# 6  Darshan  Shreyas    10      12          22      188.6           45.5
# 7     Nats    Priya    12      15          27      189.3           44.4
# 9    Priya  Shreyas    10      15          25      168.0           40.0
# 5  Darshan    Priya     9      15          24      155.4           37.5

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
#   Player_x Player_y Player_z  Wins  Losses  TotalGames  AvgPoints  \
# 6  Darshan     Nats  Shreyas     4       2           6      278.3
# 3    Akash     Nats  Shreyas     5       3           8      247.5
# 4    Akash    Priya  Shreyas     5       4           9      233.3
# 2    Akash     Nats    Priya     6       5          11      233.6
# 5  Darshan     Nats    Priya     3       4           7      180.0
# 8     Nats    Priya  Shreyas     3       6           9      142.2
# 7  Darshan    Priya  Shreyas     1       4           5       82.0
#
#    WinPercentage
# 6           66.7
# 3           62.5
# 4           55.6
# 2           54.5
# 5           42.9
# 8           33.3
# 7           20.0

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 0     Nats            6
# 2  Shreyas            5
# 4    Akash            5
# 1    Priya            3
# 3  Darshan            3

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/16 [00:00<?, ?it/s]
#  12%|█▎        | 2/16 [00:00<00:00, 18.25it/s]
#  25%|██▌       | 4/16 [00:00<00:00, 13.96it/s]
#  44%|████▍     | 7/16 [00:00<00:00, 16.51it/s]
#  56%|█████▋    | 9/16 [00:00<00:00, 14.61it/s]
#  69%|██████▉   | 11/16 [00:00<00:00, 15.60it/s]
#  81%|████████▏ | 13/16 [00:00<00:00, 14.38it/s]
#  94%|█████████▍| 15/16 [00:00<00:00, 15.17it/s]
# 100%|██████████| 16/16 [00:01<00:00, 15.42it/s]
# International Friendly #2
# <style type="text/css">
# </style>
# <table id="T_cb540">
#   <thead>
#     <tr>
#       <th id="T_cb540_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_cb540_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_cb540_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_cb540_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_cb540_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_cb540_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_cb540_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_cb540_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_cb540_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_cb540_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_cb540_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_cb540_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cb540_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cb540_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_cb540_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_cb540_row0_col3" class="data row0 col3" >1167 (+10)</td>
#       <td id="T_cb540_row0_col4" class="data row0 col4" >620</td>
#       <td id="T_cb540_row0_col5" class="data row0 col5" >58</td>
#       <td id="T_cb540_row0_col6" class="data row0 col6" >11</td>
#       <td id="T_cb540_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_cb540_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_cb540_row0_col9" class="data row0 col9" >15</td>
#       <td id="T_cb540_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_cb540_row0_col11" class="data row0 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_cb540_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_cb540_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_cb540_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_cb540_row1_col3" class="data row1 col3" >1037 (0)</td>
#       <td id="T_cb540_row1_col4" class="data row1 col4" >559</td>
#       <td id="T_cb540_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_cb540_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_cb540_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_cb540_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_cb540_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_cb540_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_cb540_row1_col11" class="data row1 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_cb540_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_cb540_row2_col1" class="data row2 col1" >▲ 1</td>
#       <td id="T_cb540_row2_col2" class="data row2 col2" >Nats</td>
#       <td id="T_cb540_row2_col3" class="data row2 col3" >1009 (+8)</td>
#       <td id="T_cb540_row2_col4" class="data row2 col4" >535</td>
#       <td id="T_cb540_row2_col5" class="data row2 col5" >49</td>
#       <td id="T_cb540_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_cb540_row2_col7" class="data row2 col7" >10</td>
#       <td id="T_cb540_row2_col8" class="data row2 col8" >9</td>
#       <td id="T_cb540_row2_col9" class="data row2 col9" >11</td>
#       <td id="T_cb540_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_cb540_row2_col11" class="data row2 col11" >10</td>
#     </tr>
#     <tr>
#       <td id="T_cb540_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_cb540_row3_col1" class="data row3 col1" >▼ 1</td>
#       <td id="T_cb540_row3_col2" class="data row3 col2" >Ani</td>
#       <td id="T_cb540_row3_col3" class="data row3 col3" >1005 (0)</td>
#       <td id="T_cb540_row3_col4" class="data row3 col4" >283</td>
#       <td id="T_cb540_row3_col5" class="data row3 col5" >49</td>
#       <td id="T_cb540_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_cb540_row3_col7" class="data row3 col7" >8</td>
#       <td id="T_cb540_row3_col8" class="data row3 col8" >6</td>
#       <td id="T_cb540_row3_col9" class="data row3 col9" >5</td>
#       <td id="T_cb540_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_cb540_row3_col11" class="data row3 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_cb540_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_cb540_row4_col1" class="data row4 col1" >▲ 1</td>
#       <td id="T_cb540_row4_col2" class="data row4 col2" >Shreyas</td>
#       <td id="T_cb540_row4_col3" class="data row4 col3" >1000 (0)</td>
#       <td id="T_cb540_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_cb540_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_cb540_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_cb540_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_cb540_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_cb540_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_cb540_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_cb540_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cb540_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_cb540_row5_col1" class="data row5 col1" >▲ 2</td>
#       <td id="T_cb540_row5_col2" class="data row5 col2" >Naati</td>
#       <td id="T_cb540_row5_col3" class="data row5 col3" >997 (0)</td>
#       <td id="T_cb540_row5_col4" class="data row5 col4" >289</td>
#       <td id="T_cb540_row5_col5" class="data row5 col5" >49</td>
#       <td id="T_cb540_row5_col6" class="data row5 col6" >8</td>
#       <td id="T_cb540_row5_col7" class="data row5 col7" >9</td>
#       <td id="T_cb540_row5_col8" class="data row5 col8" >6</td>
#       <td id="T_cb540_row5_col9" class="data row5 col9" >5</td>
#       <td id="T_cb540_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_cb540_row5_col11" class="data row5 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_cb540_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_cb540_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_cb540_row6_col2" class="data row6 col2" >Darshan</td>
#       <td id="T_cb540_row6_col3" class="data row6 col3" >997 (-3)</td>
#       <td id="T_cb540_row6_col4" class="data row6 col4" >61</td>
#       <td id="T_cb540_row6_col5" class="data row6 col5" >47</td>
#       <td id="T_cb540_row6_col6" class="data row6 col6" >4</td>
#       <td id="T_cb540_row6_col7" class="data row6 col7" >5</td>
#       <td id="T_cb540_row6_col8" class="data row6 col8" >4</td>
#       <td id="T_cb540_row6_col9" class="data row6 col9" >2</td>
#       <td id="T_cb540_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_cb540_row6_col11" class="data row6 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cb540_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_cb540_row7_col1" class="data row7 col1" >▼ 3</td>
#       <td id="T_cb540_row7_col2" class="data row7 col2" >Priya</td>
#       <td id="T_cb540_row7_col3" class="data row7 col3" >984 (-16)</td>
#       <td id="T_cb540_row7_col4" class="data row7 col4" >61</td>
#       <td id="T_cb540_row7_col5" class="data row7 col5" >42</td>
#       <td id="T_cb540_row7_col6" class="data row7 col6" >4</td>
#       <td id="T_cb540_row7_col7" class="data row7 col7" >9</td>
#       <td id="T_cb540_row7_col8" class="data row7 col8" >8</td>
#       <td id="T_cb540_row7_col9" class="data row7 col9" >1</td>
#       <td id="T_cb540_row7_col10" class="data row7 col10" >0</td>
#       <td id="T_cb540_row7_col11" class="data row7 col11" >3</td>
#     </tr>
#     <tr>
#       <td id="T_cb540_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_cb540_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_cb540_row8_col2" class="data row8 col2" >Abhi</td>
#       <td id="T_cb540_row8_col3" class="data row8 col3" >942 (0)</td>
#       <td id="T_cb540_row8_col4" class="data row8 col4" >484</td>
#       <td id="T_cb540_row8_col5" class="data row8 col5" >44</td>
#       <td id="T_cb540_row8_col6" class="data row8
#  -----------------------------

# %% [markdown]
# ### Fin!
