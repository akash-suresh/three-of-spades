# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 4
TOURNAMENT_TYPE = TournamentTypes.CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Championship #4
# Players participating in this Championship are : ['Akash', 'Ani', 'Nats', 'Naati', 'Prateek']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 0    Akash    32          58      218.1        12650           55.2
# 1      Ani    32          58      212.2        12310           55.2
# 4  Prateek    29          58      193.1        11200           50.0
# 3     Nats    28          58      189.0        10960           48.3
# 2    Naati    27          58      185.0        10730           46.6

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 0    Akash      Ani    10       4          14      281.4           71.4
# 3    Akash  Prateek    12       9          21      227.6           57.1
# 5      Ani     Nats     9       7          16      215.6           56.2
# 6      Ani  Prateek    16      13          29      204.8           55.2
# 2    Akash     Nats    18      16          34      205.9           52.9
# 4      Ani    Naati    14      13          27      203.3           51.9
# 1    Akash    Naati    17      16          33      197.9           51.5
# 9     Nats  Prateek     9      10          19      181.1           47.4
# 7    Naati     Nats    13      16          29      174.5           44.8
# 8    Naati  Prateek     4       6          10      161.0           40.0

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
#   Player_x Player_y Player_z  Wins  Losses  TotalGames  AvgPoints  \
# 0    Akash      Ani    Naati     6       2           8      285.0
# 5    Akash     Nats  Prateek     5       3           8      241.2
# 3    Akash    Naati     Nats     9      10          19      181.1
# 6      Ani    Naati     Nats     3       4           7      168.6
#
#    WinPercentage
# 0           75.0
# 5           62.5
# 3           47.4
# 6           42.9

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 3    Naati            8
# 0    Akash            6
# 1      Ani            5
# 4  Prateek            5
# 2     Nats            3

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/14 [00:00<?, ?it/s]
#  14%|█▍        | 2/14 [00:00<00:00, 16.65it/s]
#  29%|██▊       | 4/14 [00:00<00:00, 13.59it/s]
#  43%|████▎     | 6/14 [00:00<00:00, 15.55it/s]
#  57%|█████▋    | 8/14 [00:00<00:00, 15.26it/s]
#  71%|███████▏  | 10/14 [00:00<00:00, 13.52it/s]
#  86%|████████▌ | 12/14 [00:00<00:00, 14.40it/s]
# 100%|██████████| 14/14 [00:00<00:00, 13.33it/s]
# 100%|██████████| 14/14 [00:01<00:00, 13.99it/s]
# Championship #4
# <style type="text/css">
# </style>
# <table id="T_dd42d">
#   <thead>
#     <tr>
#       <th id="T_dd42d_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_dd42d_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_dd42d_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_dd42d_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_dd42d_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_dd42d_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_dd42d_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_dd42d_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_dd42d_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_dd42d_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_dd42d_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_dd42d_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dd42d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_dd42d_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_dd42d_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_dd42d_row0_col3" class="data row0 col3" >1065 (+10)</td>
#       <td id="T_dd42d_row0_col4" class="data row0 col4" >205</td>
#       <td id="T_dd42d_row0_col5" class="data row0 col5" >58</td>
#       <td id="T_dd42d_row0_col6" class="data row0 col6" >9</td>
#       <td id="T_dd42d_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_dd42d_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_dd42d_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_dd42d_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_dd42d_row0_col11" class="data row0 col11" >2</td>
#     </tr>
#     <tr>
#       <td id="T_dd42d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_dd42d_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_dd42d_row1_col2" class="data row1 col2" >Abhi</td>
#       <td id="T_dd42d_row1_col3" class="data row1 col3" >1027 (0)</td>
#       <td id="T_dd42d_row1_col4" class="data row1 col4" >147</td>
#       <td id="T_dd42d_row1_col5" class="data row1 col5" >55</td>
#       <td id="T_dd42d_row1_col6" class="data row1 col6" >8</td>
#       <td id="T_dd42d_row1_col7" class="data row1 col7" >6</td>
#       <td id="T_dd42d_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_dd42d_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_dd42d_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_dd42d_row1_col11" class="data row1 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_dd42d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_dd42d_row2_col1" class="data row2 col1" >▲ 1</td>
#       <td id="T_dd42d_row2_col2" class="data row2 col2" >Ani</td>
#       <td id="T_dd42d_row2_col3" class="data row2 col3" >1023 (+9)</td>
#       <td id="T_dd42d_row2_col4" class="data row2 col4" >125</td>
#       <td id="T_dd42d_row2_col5" class="data row2 col5" >55</td>
#       <td id="T_dd42d_row2_col6" class="data row2 col6" >4</td>
#       <td id="T_dd42d_row2_col7" class="data row2 col7" >8</td>
#       <td id="T_dd42d_row2_col8" class="data row2 col8" >5</td>
#       <td id="T_dd42d_row2_col9" class="data row2 col9" >4</td>
#       <td id="T_dd42d_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_dd42d_row2_col11" class="data row2 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_dd42d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_dd42d_row3_col1" class="data row3 col1" >▼ 1</td>
#       <td id="T_dd42d_row3_col2" class="data row3 col2" >Naati</td>
#       <td id="T_dd42d_row3_col3" class="data row3 col3" >1010 (-8)</td>
#       <td id="T_dd42d_row3_col4" class="data row3 col4" >205</td>
#       <td id="T_dd42d_row3_col5" class="data row3 col5" >51</td>
#       <td id="T_dd42d_row3_col6" class="data row3 col6" >10</td>
#       <td id="T_dd42d_row3_col7" class="data row3 col7" >9</td>
#       <td id="T_dd42d_row3_col8" class="data row3 col8" >5</td>
#       <td id="T_dd42d_row3_col9" class="data row3 col9" >4</td>
#       <td id="T_dd42d_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_dd42d_row3_col11" class="data row3 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_dd42d_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_dd42d_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_dd42d_row4_col2" class="data row4 col2" >Prateek</td>
#       <td id="T_dd42d_row4_col3" class="data row4 col3" >990 (0)</td>
#       <td id="T_dd42d_row4_col4" class="data row4 col4" >205</td>
#       <td id="T_dd42d_row4_col5" class="data row4 col5" >48</td>
#       <td id="T_dd42d_row4_col6" class="data row4 col6" >7</td>
#       <td id="T_dd42d_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_dd42d_row4_col8" class="data row4 col8" >5</td>
#       <td id="T_dd42d_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_dd42d_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_dd42d_row4_col11" class="data row4 col11" >2</td>
#     </tr>
#     <tr>
#       <td id="T_dd42d_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_dd42d_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_dd42d_row5_col2" class="data row5 col2" >Nats</td>
#       <td id="T_dd42d_row5_col3" class="data row5 col3" >977 (-2)</td>
#       <td id="T_dd42d_row5_col4" class="data row5 col4" >138</td>
#       <td id="T_dd42d_row5_col5" class="data row5 col5" >44</td>
#       <td id="T_dd42d_row5_col6" class="data row5 col6" >3</td>
#       <td id="T_dd42d_row5_col7" class="data row5 col7" >6</td>
#       <td id="T_dd42d_row5_col8" class="data row5 col8" >9</td>
#       <td id="T_dd42d_row5_col9" class="data row5 col9" >2</td>
#       <td id="T_dd42d_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_dd42d_row5_col11" class="data row5 col11" >3</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
