# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 1
TOURNAMENT_TYPE = TournamentTypes.FRIENDLY
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades International Friendly #1
# Players participating in this International Friendly are : ['Akash', 'Abhi', 'Yandigeri', 'Nats', 'Prateek']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#       Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 0       Abhi     8           9      195.6         1760           88.9
# 1      Akash     5           9      133.3         1200           55.6
# 4  Yandigeri     4           9      111.1         1000           44.4
# 2       Nats     4           9      107.8          970           44.4
# 3    Prateek     3           9       75.6          680           33.3

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Player_z, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#       Player  Bid and Won
# 0      Akash            2
# 2  Yandigeri            2
# 1       Abhi            0
# 3       Nats            0
# 4    Prateek            0

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/28 [00:00<?, ?it/s]
#   7%|▋         | 2/28 [00:00<00:01, 17.56it/s]
#  14%|█▍        | 4/28 [00:00<00:01, 14.95it/s]
#  25%|██▌       | 7/28 [00:00<00:01, 16.81it/s]
#  32%|███▏      | 9/28 [00:00<00:01, 17.57it/s]
#  39%|███▉      | 11/28 [00:00<00:01, 15.67it/s]
#  46%|████▋     | 13/28 [00:00<00:00, 16.45it/s]
#  54%|█████▎    | 15/28 [00:00<00:00, 15.32it/s]
#  61%|██████    | 17/28 [00:01<00:00, 15.29it/s]
#  68%|██████▊   | 19/28 [00:01<00:00, 16.18it/s]
#  79%|███████▊  | 22/28 [00:01<00:00, 17.93it/s]
#  86%|████████▌ | 24/28 [00:01<00:00, 16.63it/s]
#  93%|█████████▎| 26/28 [00:01<00:00, 17.15it/s]
# 100%|██████████| 28/28 [00:01<00:00, 16.89it/s]
# International Friendly #1
# <style type="text/css">
# </style>
# <table id="T_c4aeb">
#   <thead>
#     <tr>
#       <th id="T_c4aeb_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_c4aeb_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_c4aeb_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_c4aeb_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_c4aeb_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_c4aeb_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_c4aeb_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_c4aeb_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_c4aeb_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_c4aeb_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_c4aeb_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_c4aeb_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c4aeb_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c4aeb_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_c4aeb_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_c4aeb_row0_col3" class="data row0 col3" >1151 (0)</td>
#       <td id="T_c4aeb_row0_col4" class="data row0 col4" >335</td>
#       <td id="T_c4aeb_row0_col5" class="data row0 col5" >61</td>
#       <td id="T_c4aeb_row0_col6" class="data row0 col6" >11</td>
#       <td id="T_c4aeb_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_c4aeb_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_c4aeb_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_c4aeb_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_c4aeb_row0_col11" class="data row0 col11" >2</td>
#     </tr>
#     <tr>
#       <td id="T_c4aeb_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c4aeb_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_c4aeb_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_c4aeb_row1_col3" class="data row1 col3" >1030 (-3)</td>
#       <td id="T_c4aeb_row1_col4" class="data row1 col4" >335</td>
#       <td id="T_c4aeb_row1_col5" class="data row1 col5" >52</td>
#       <td id="T_c4aeb_row1_col6" class="data row1 col6" >7</td>
#       <td id="T_c4aeb_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_c4aeb_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_c4aeb_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_c4aeb_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_c4aeb_row1_col11" class="data row1 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_c4aeb_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c4aeb_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_c4aeb_row2_col2" class="data row2 col2" >Yandigeri</td>
#       <td id="T_c4aeb_row2_col3" class="data row2 col3" >999 (-1)</td>
#       <td id="T_c4aeb_row2_col4" class="data row2 col4" >9</td>
#       <td id="T_c4aeb_row2_col5" class="data row2 col5" >44</td>
#       <td id="T_c4aeb_row2_col6" class="data row2 col6" >22</td>
#       <td id="T_c4aeb_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_c4aeb_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_c4aeb_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_c4aeb_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_c4aeb_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_c4aeb_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c4aeb_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_c4aeb_row3_col2" class="data row3 col2" >Ani</td>
#       <td id="T_c4aeb_row3_col3" class="data row3 col3" >997 (0)</td>
#       <td id="T_c4aeb_row3_col4" class="data row3 col4" >206</td>
#       <td id="T_c4aeb_row3_col5" class="data row3 col5" >49</td>
#       <td id="T_c4aeb_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_c4aeb_row3_col7" class="data row3 col7" >8</td>
#       <td id="T_c4aeb_row3_col8" class="data row3 col8" >6</td>
#       <td id="T_c4aeb_row3_col9" class="data row3 col9" >4</td>
#       <td id="T_c4aeb_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_c4aeb_row3_col11" class="data row3 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_c4aeb_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c4aeb_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_c4aeb_row4_col2" class="data row4 col2" >Naati</td>
#       <td id="T_c4aeb_row4_col3" class="data row4 col3" >997 (0)</td>
#       <td id="T_c4aeb_row4_col4" class="data row4 col4" >289</td>
#       <td id="T_c4aeb_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_c4aeb_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_c4aeb_row4_col7" class="data row4 col7" >9</td>
#       <td id="T_c4aeb_row4_col8" class="data row4 col8" >6</td>
#       <td id="T_c4aeb_row4_col9" class="data row4 col9" >5</td>
#       <td id="T_c4aeb_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_c4aeb_row4_col11" class="data row4 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_c4aeb_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_c4aeb_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_c4aeb_row5_col2" class="data row5 col2" >Abhi</td>
#       <td id="T_c4aeb_row5_col3" class="data row5 col3" >987 (+6)</td>
#       <td id="T_c4aeb_row5_col4" class="data row5 col4" >260</td>
#       <td id="T_c4aeb_row5_col5" class="data row5 col5" >49</td>
#       <td id="T_c4aeb_row5_col6" class="data row5 col6" >6</td>
#       <td id="T_c4aeb_row5_col7" class="data row5 col7" >6</td>
#       <td id="T_c4aeb_row5_col8" class="data row5 col8" >7</td>
#       <td id="T_c4aeb_row5_col9" class="data row5 col9" >3</td>
#       <td id="T_c4aeb_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_c4aeb_row5_col11" class="data row5 col11" >3</td>
#     </tr>
#     <tr>
#       <td id="T_c4aeb_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_c4aeb_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_c4aeb_row6_col2" class="data row6 col2" >Nats</td>
#       <td id="T_c4aeb_row6_col3" class="data row6 col3" >977 (0)</td>
#       <td id="T_c4aeb_row6_col4" class="data row6 col4" >268</td>
#       <td id="T_c4aeb_row6_col5" class="data row6 col5" >46</td>
#       <td id="T_c4aeb_row6_col6" class="data row6 col6" >7</td>
#       <td id="T_c4aeb_row6_col7" class="data row6 col7" >8</td>
#       <td id="T_c4aeb_row6_col8" class="data row6 col8" >9</td>
#       <td id="T_c4aeb_row6_col9" class="data row6 col9" >7</td>
#       <td id="T_c4aeb_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_c4aeb_row6_col11" class="data row6 col11" >6</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
