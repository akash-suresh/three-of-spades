# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.ranking_system import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 3
TOURNAMENT_TYPE = TournamentTypes.CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Championship #3
# Players participating in this Championship are : ['Abhi', 'Akash', 'Nats', 'Naati', 'Prateek']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 1    Akash    47          80      222.9        17830           58.8
# 2    Naati    45          80      209.2        16740           56.2
# 0     Abhi    45          80      206.4        16510           56.2
# 4  Prateek    38          80      177.5        14200           47.5
# 3     Nats    34          80      157.8        12620           42.5

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 0     Abhi    Akash    21       9          30      257.7           70.0
# 1     Abhi    Naati    20      10          30      232.3           66.7
# 4    Akash    Naati    27      15          42      242.9           64.3
# 6    Akash  Prateek    13       8          21      243.8           61.9
# 8    Naati  Prateek    17      14          31      197.4           54.8
# 3     Abhi  Prateek    22      19          41      194.9           53.7
# 5    Akash     Nats    16      15          31      189.0           51.6
# 2     Abhi     Nats    17      18          35      179.1           48.6
# 7    Naati     Nats    15      16          31      179.7           48.4
# 9     Nats  Prateek    12      20          32      138.4           37.5

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
#   Player_x Player_y Player_z  Wins  Losses  TotalGames  AvgPoints  \
# 7    Akash    Naati  Prateek     6       1           7      338.6
# 3     Abhi    Naati     Nats     6       2           8      261.2
# 0     Abhi    Akash    Naati     8       3          11      256.4
# 2     Abhi    Akash  Prateek     4       2           6      256.7
# 4     Abhi    Naati  Prateek     7       4          11      209.1
# 1     Abhi    Akash     Nats     5       3           8      228.8
# 5     Abhi     Nats  Prateek     7       7          14      185.0
# 6    Akash    Naati     Nats     6       6          12      190.0
# 9    Naati     Nats  Prateek     3       4           7      142.9
#
#    WinPercentage
# 7           85.7
# 3           75.0
# 0           72.7
# 2           66.7
# 4           63.6
# 1           62.5
# 5           50.0
# 6           50.0
# 9           42.9

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 1    Akash            7
# 3    Naati            6
# 0     Abhi            5
# 4  Prateek            5
# 2     Nats            2

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/12 [00:00<?, ?it/s]
#  17%|█▋        | 2/12 [00:00<00:00, 17.58it/s]
#  33%|███▎      | 4/12 [00:00<00:00, 15.37it/s]
#  50%|█████     | 6/12 [00:00<00:00, 16.60it/s]
#  67%|██████▋   | 8/12 [00:00<00:00, 14.88it/s]
#  83%|████████▎ | 10/12 [00:00<00:00, 14.27it/s]
# 100%|██████████| 12/12 [00:00<00:00, 15.33it/s]
# 100%|██████████| 12/12 [00:00<00:00, 15.32it/s]
# Championship #3
# <style type="text/css">
# </style>
# <table id="T_d4593">
#   <thead>
#     <tr>
#       <th id="T_d4593_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_d4593_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_d4593_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_d4593_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_d4593_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_d4593_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_d4593_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d4593_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d4593_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_d4593_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_d4593_row0_col3" class="data row0 col3" >1054 (+26)</td>
#       <td id="T_d4593_row0_col4" class="data row0 col4" >147</td>
#       <td id="T_d4593_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_d4593_row0_col6" class="data row0 col6" >8</td>
#     </tr>
#     <tr>
#       <td id="T_d4593_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d4593_row1_col1" class="data row1 col1" >▲ 1</td>
#       <td id="T_d4593_row1_col2" class="data row1 col2" >Abhi</td>
#       <td id="T_d4593_row1_col3" class="data row1 col3" >1027 (+15)</td>
#       <td id="T_d4593_row1_col4" class="data row1 col4" >147</td>
#       <td id="T_d4593_row1_col5" class="data row1 col5" >55</td>
#       <td id="T_d4593_row1_col6" class="data row1 col6" >8</td>
#     </tr>
#     <tr>
#       <td id="T_d4593_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d4593_row2_col1" class="data row2 col1" >▲ 1</td>
#       <td id="T_d4593_row2_col2" class="data row2 col2" >Naati</td>
#       <td id="T_d4593_row2_col3" class="data row2 col3" >1018 (+17)</td>
#       <td id="T_d4593_row2_col4" class="data row2 col4" >147</td>
#       <td id="T_d4593_row2_col5" class="data row2 col5" >53</td>
#       <td id="T_d4593_row2_col6" class="data row2 col6" >8</td>
#     </tr>
#     <tr>
#       <td id="T_d4593_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d4593_row3_col1" class="data row3 col1" >▼ 2</td>
#       <td id="T_d4593_row3_col2" class="data row3 col2" >Ani</td>
#       <td id="T_d4593_row3_col3" class="data row3 col3" >1013 (0)</td>
#       <td id="T_d4593_row3_col4" class="data row3 col4" >67</td>
#       <td id="T_d4593_row3_col5" class="data row3 col5" >55</td>
#       <td id="T_d4593_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d4593_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_d4593_row4_col1" class="data row4 col1" >▲ 1</td>
#       <td id="T_d4593_row4_col2" class="data row4 col2" >Prateek</td>
#       <td id="T_d4593_row4_col3" class="data row4 col3" >989 (-6)</td>
#       <td id="T_d4593_row4_col4" class="data row4 col4" >147</td>
#       <td id="T_d4593_row4_col5" class="data row4 col5" >48</td>
#       <td id="T_d4593_row4_col6" class="data row4 col6" >7</td>
#     </tr>
#     <tr>
#       <td id="T_d4593_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_d4593_row5_col1" class="data row5 col1" >▼ 1</td>
#       <td id="T_d4593_row5_col2" class="data row5 col2" >Nats</td>
#       <td id="T_d4593_row5_col3" class="data row5 col3" >979 (-21)</td>
#       <td id="T_d4593_row5_col4" class="data row5 col4" >80</td>
#       <td id="T_d4593_row5_col5" class="data row5 col5" >42</td>
#       <td id="T_d4593_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
