# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 5
TOURNAMENT_TYPE = TournamentTypes.MINI_CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Mini Championship #5
# Players participating in this Mini Championship are : ['Chirag', 'Ani', 'Prateek', 'Nats', 'Akash']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 0    Akash    19          27      184.6         4985           70.4
# 4  Prateek    17          27      168.1         4540           63.0
# 3     Nats    15          27      139.4         3765           55.6
# 2   Chirag    13          27      120.2         3245           48.1
# 1      Ani    11          27      100.9         2725           40.7

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 3    Akash  Prateek    11       2          13      224.6           84.6
# 2    Akash     Nats    10       3          13      192.7           76.9
# 1    Akash   Chirag     9       4          13      174.2           69.2
# 8   Chirag  Prateek     7       4          11      170.0           63.6
# 7   Chirag     Nats     7       6          13      127.3           53.8
# 6      Ani  Prateek     7       6          13      133.1           53.8
# 5      Ani     Nats     5       6          11      107.7           45.5

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
#   Player_x Player_y Player_z  Wins  Losses  TotalGames  AvgPoints  \
# 4    Akash   Chirag  Prateek     5       0           5      262.0
# 3    Akash   Chirag     Nats     4       2           6      159.2
#
#    WinPercentage
# 4          100.0
# 3           66.7

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 2  Prateek            6
# 4    Akash            6
# 3     Nats            6
# 0   Chirag            1
# 1      Ani            0

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/28 [00:00<?, ?it/s]
#   7%|▋         | 2/28 [00:00<00:01, 18.32it/s]
#  14%|█▍        | 4/28 [00:00<00:01, 15.19it/s]
#  21%|██▏       | 6/28 [00:00<00:01, 16.90it/s]
#  29%|██▊       | 8/28 [00:00<00:01, 16.92it/s]
#  36%|███▌      | 10/28 [00:00<00:01, 15.77it/s]
#  43%|████▎     | 12/28 [00:00<00:00, 16.32it/s]
#  50%|█████     | 14/28 [00:00<00:00, 16.50it/s]
#  57%|█████▋    | 16/28 [00:01<00:00, 13.75it/s]
#  64%|██████▍   | 18/28 [00:01<00:00, 13.86it/s]
#  71%|███████▏  | 20/28 [00:01<00:00, 14.98it/s]
#  82%|████████▏ | 23/28 [00:01<00:00, 16.09it/s]
#  89%|████████▉ | 25/28 [00:01<00:00, 15.33it/s]
#  96%|█████████▋| 27/28 [00:01<00:00, 15.86it/s]
# 100%|██████████| 28/28 [00:01<00:00, 15.80it/s]
# Mini Championship #5
# <style type="text/css">
# </style>
# <table id="T_aeda5">
#   <thead>
#     <tr>
#       <th id="T_aeda5_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_aeda5_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_aeda5_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_aeda5_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_aeda5_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_aeda5_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_aeda5_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_aeda5_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_aeda5_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_aeda5_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_aeda5_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_aeda5_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aeda5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_aeda5_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_aeda5_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_aeda5_row0_col3" class="data row0 col3" >1207 (+9)</td>
#       <td id="T_aeda5_row0_col4" class="data row0 col4" >961</td>
#       <td id="T_aeda5_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_aeda5_row0_col6" class="data row0 col6" >14</td>
#       <td id="T_aeda5_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_aeda5_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_aeda5_row0_col9" class="data row0 col9" >26</td>
#       <td id="T_aeda5_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_aeda5_row0_col11" class="data row0 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_aeda5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_aeda5_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_aeda5_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_aeda5_row1_col3" class="data row1 col3" >1061 (+7)</td>
#       <td id="T_aeda5_row1_col4" class="data row1 col4" >792</td>
#       <td id="T_aeda5_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_aeda5_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_aeda5_row1_col7" class="data row1 col7" >9</td>
#       <td id="T_aeda5_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_aeda5_row1_col9" class="data row1 col9" >9</td>
#       <td id="T_aeda5_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_aeda5_row1_col11" class="data row1 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_aeda5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_aeda5_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_aeda5_row2_col2" class="data row2 col2" >Nats</td>
#       <td id="T_aeda5_row2_col3" class="data row2 col3" >1031 (+2)</td>
#       <td id="T_aeda5_row2_col4" class="data row2 col4" >876</td>
#       <td id="T_aeda5_row2_col5" class="data row2 col5" >49</td>
#       <td id="T_aeda5_row2_col6" class="data row2 col6" >12</td>
#       <td id="T_aeda5_row2_col7" class="data row2 col7" >10</td>
#       <td id="T_aeda5_row2_col8" class="data row2 col8" >10</td>
#       <td id="T_aeda5_row2_col9" class="data row2 col9" >16</td>
#       <td id="T_aeda5_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_aeda5_row2_col11" class="data row2 col11" >16</td>
#     </tr>
#     <tr>
#       <td id="T_aeda5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_aeda5_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_aeda5_row3_col2" class="data row3 col2" >Ani</td>
#       <td id="T_aeda5_row3_col3" class="data row3 col3" >1000 (-5)</td>
#       <td id="T_aeda5_row3_col4" class="data row3 col4" >310</td>
#       <td id="T_aeda5_row3_col5" class="data row3 col5" >49</td>
#       <td id="T_aeda5_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_aeda5_row3_col7" class="data row3 col7" >8</td>
#       <td id="T_aeda5_row3_col8" class="data row3 col8" >6</td>
#       <td id="T_aeda5_row3_col9" class="data row3 col9" >5</td>
#       <td id="T_aeda5_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_aeda5_row3_col11" class="data row3 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_aeda5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_aeda5_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_aeda5_row4_col2" class="data row4 col2" >Shreyas</td>
#       <td id="T_aeda5_row4_col3" class="data row4 col3" >1000 (0)</td>
#       <td id="T_aeda5_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_aeda5_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_aeda5_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_aeda5_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_aeda5_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_aeda5_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_aeda5_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_aeda5_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aeda5_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_aeda5_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_aeda5_row5_col2" class="data row5 col2" >Skanda</td>
#       <td id="T_aeda5_row5_col3" class="data row5 col3" >1000 (0)</td>
#       <td id="T_aeda5_row5_col4" class="data row5 col4" >172</td>
#       <td id="T_aeda5_row5_col5" class="data row5 col5" >46</td>
#       <td id="T_aeda5_row5_col6" class="data row5 col6" >13</td>
#       <td id="T_aeda5_row5_col7" class="data row5 col7" >5</td>
#       <td id="T_aeda5_row5_col8" class="data row5 col8" >6</td>
#       <td id="T_aeda5_row5_col9" class="data row5 col9" >2</td>
#       <td id="T_aeda5_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_aeda5_row5_col11" class="data row5 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_aeda5_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_aeda5_row6_col1" class="data row6 col1" >▲ 1</td>
#       <td id="T_aeda5_row6_col2" class="data row6 col2" >Yandigeri</td>
#       <td id="T_aeda5_row6_col3" class="data row6 col3" >999 (0)</td>
#       <td id="T_aeda5_row6_col4" class="data row6 col4" >9</td>
#       <td id="T_aeda5_row6_col5" class="data row6 col5" >44</td>
#       <td id="T_aeda5_row6_col6" class="data row6 col6" >22</td>
#       <td id="T_aeda5_row6_col7" class="data row6 col7" >3</td>
#       <td id="T_aeda5_row6_col8" class="data row6 col8" >3</td>
#       <td id="T_aeda5_row6_col9" class="data row6 col9" >0</td>
#       <td id="T_aeda5_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_aeda5_row6_col11" class="data row6 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aeda5_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_aeda5_row7_col1" class="data row7 col1" >▼ 1</td>
#       <td id="T_aeda5_row7_col2" class="data row7 col2" >Chirag</td>
#       <td id="T_aeda5_row7_col3" class="data row7 col3" >999 (-1)</td>
#       <td id="T_aeda5_row7_col4" class="data row7 col4" >27</td>
#       <td id="T_aeda5_row7_col5" class="data row7 col5" >48</td>
#       <td id="T_aeda5_row7_col6" class="data row7 col6" >3</td>
#       <td id="T_aeda5_row7_col7" class="data row7 col7" >4</td>
#       <td id="T_aeda5_row7_col8" class="data row7 col8" >4</td>
#       <td id="T_aeda5_row7_col9" class="data row7 col9" >0</td>
#       <td id="T_aeda5_row7_col10" class="data row7 col10" >0</td>
#       <td id="T_aeda5_row7_col11" class="data row7 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aeda5_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_aeda5_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_aeda5_row8_col2" class="data row8 col2" >Naati</td>
#       <td id="T_aeda5_row8_col3" class="data row8 col3" >997 (0)</td>
#       <td id="T_aeda5_row8_col4" class="data row8 col4" >289</td>
#       <td id="T_aeda5_row8_col5" class="data row8 col5" >49</td>
#       <td id="T_aeda5_row8_col6" class="data row
#  -----------------------------

# %% [markdown]
# ### Fin!
