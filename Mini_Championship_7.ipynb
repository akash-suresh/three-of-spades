# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 7
TOURNAMENT_TYPE = TournamentTypes.MINI_CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Mini Championship #7
# Players participating in this Mini Championship are : ['Ani', 'Nats', 'Prateek', 'Akash']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 3  Prateek    29          48      132.8         6375           60.4
# 0    Akash    24          48      110.2         5290           50.0
# 2     Nats    21          48       99.1         4755           43.8
# 1      Ani    22          48       96.5         4630           45.8

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 2    Akash  Prateek    11       6          17      142.9           64.7
# 4      Ani  Prateek     9       6          15      126.0           60.0
# 5     Nats  Prateek     9       7          16      119.7           56.2
# 0    Akash      Ani     7       9          16       90.6           43.8
# 1    Akash     Nats     6       9          15       91.3           40.0
# 3      Ani     Nats     6      11          17       72.4           35.3

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Player_z, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 1     Nats           12
# 2  Prateek            7
# 0      Ani            3
# 3    Akash            2

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/28 [00:00<?, ?it/s]
#   7%|▋         | 2/28 [00:00<00:01, 13.65it/s]
#  14%|█▍        | 4/28 [00:00<00:01, 12.92it/s]
#  21%|██▏       | 6/28 [00:00<00:01, 15.11it/s]
#  29%|██▊       | 8/28 [00:00<00:01, 15.49it/s]
#  36%|███▌      | 10/28 [00:00<00:01,  9.47it/s]
#  43%|████▎     | 12/28 [00:01<00:02,  5.54it/s]
#  46%|████▋     | 13/28 [00:01<00:02,  5.36it/s]
#  50%|█████     | 14/28 [00:01<00:02,  5.32it/s]
#  54%|█████▎    | 15/28 [00:02<00:02,  4.78it/s]
#  57%|█████▋    | 16/28 [00:02<00:03,  3.62it/s]
#  61%|██████    | 17/28 [00:02<00:02,  3.81it/s]
#  64%|██████▍   | 18/28 [00:03<00:02,  3.99it/s]
#  68%|██████▊   | 19/28 [00:03<00:02,  4.03it/s]
#  71%|███████▏  | 20/28 [00:03<00:02,  3.83it/s]
#  75%|███████▌  | 21/28 [00:03<00:01,  3.83it/s]
#  79%|███████▊  | 22/28 [00:04<00:01,  4.02it/s]
#  82%|████████▏ | 23/28 [00:04<00:01,  4.67it/s]
#  86%|████████▌ | 24/28 [00:04<00:01,  3.88it/s]
#  89%|████████▉ | 25/28 [00:04<00:00,  4.34it/s]
#  93%|█████████▎| 26/28 [00:05<00:00,  4.10it/s]
# 100%|██████████| 28/28 [00:05<00:00,  5.87it/s]
# 100%|██████████| 28/28 [00:05<00:00,  5.32it/s]
# Mini Championship #7
# <style type="text/css">
# </style>
# <table id="T_5b239">
#   <thead>
#     <tr>
#       <th id="T_5b239_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_5b239_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_5b239_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_5b239_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_5b239_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_5b239_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_5b239_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_5b239_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_5b239_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_5b239_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_5b239_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_5b239_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b239_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5b239_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_5b239_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_5b239_row0_col3" class="data row0 col3" >1198 (-2)</td>
#       <td id="T_5b239_row0_col4" class="data row0 col4" >1292</td>
#       <td id="T_5b239_row0_col5" class="data row0 col5" >57</td>
#       <td id="T_5b239_row0_col6" class="data row0 col6" >14</td>
#       <td id="T_5b239_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_5b239_row0_col8" class="data row0 col8" >9</td>
#       <td id="T_5b239_row0_col9" class="data row0 col9" >34</td>
#       <td id="T_5b239_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_5b239_row0_col11" class="data row0 col11" >11</td>
#     </tr>
#     <tr>
#       <td id="T_5b239_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5b239_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_5b239_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_5b239_row1_col3" class="data row1 col3" >1081 (+7)</td>
#       <td id="T_5b239_row1_col4" class="data row1 col4" >1047</td>
#       <td id="T_5b239_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_5b239_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_5b239_row1_col7" class="data row1 col7" >9</td>
#       <td id="T_5b239_row1_col8" class="data row1 col8" >7</td>
#       <td id="T_5b239_row1_col9" class="data row1 col9" >15</td>
#       <td id="T_5b239_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_5b239_row1_col11" class="data row1 col11" >9</td>
#     </tr>
#     <tr>
#       <td id="T_5b239_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5b239_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_5b239_row2_col2" class="data row2 col2" >Nats</td>
#       <td id="T_5b239_row2_col3" class="data row2 col3" >1031 (-3)</td>
#       <td id="T_5b239_row2_col4" class="data row2 col4" >1207</td>
#       <td id="T_5b239_row2_col5" class="data row2 col5" >48</td>
#       <td id="T_5b239_row2_col6" class="data row2 col6" >13</td>
#       <td id="T_5b239_row2_col7" class="data row2 col7" >10</td>
#       <td id="T_5b239_row2_col8" class="data row2 col8" >10</td>
#       <td id="T_5b239_row2_col9" class="data row2 col9" >21</td>
#       <td id="T_5b239_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_5b239_row2_col11" class="data row2 col11" >23</td>
#     </tr>
#     <tr>
#       <td id="T_5b239_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_5b239_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_5b239_row3_col2" class="data row3 col2" >Skanda</td>
#       <td id="T_5b239_row3_col3" class="data row3 col3" >1002 (0)</td>
#       <td id="T_5b239_row3_col4" class="data row3 col4" >236</td>
#       <td id="T_5b239_row3_col5" class="data row3 col5" >47</td>
#       <td id="T_5b239_row3_col6" class="data row3 col6" >12</td>
#       <td id="T_5b239_row3_col7" class="data row3 col7" >5</td>
#       <td id="T_5b239_row3_col8" class="data row3 col8" >7</td>
#       <td id="T_5b239_row3_col9" class="data row3 col9" >3</td>
#       <td id="T_5b239_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_5b239_row3_col11" class="data row3 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_5b239_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_5b239_row4_col1" class="data row4 col1" >▲ 1</td>
#       <td id="T_5b239_row4_col2" class="data row4 col2" >Shreyas</td>
#       <td id="T_5b239_row4_col3" class="data row4 col3" >1000 (0)</td>
#       <td id="T_5b239_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_5b239_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_5b239_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_5b239_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_5b239_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_5b239_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_5b239_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_5b239_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_5b239_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_5b239_row5_col1" class="data row5 col1" >▲ 1</td>
#       <td id="T_5b239_row5_col2" class="data row5 col2" >Yandigeri</td>
#       <td id="T_5b239_row5_col3" class="data row5 col3" >999 (0)</td>
#       <td id="T_5b239_row5_col4" class="data row5 col4" >9</td>
#       <td id="T_5b239_row5_col5" class="data row5 col5" >44</td>
#       <td id="T_5b239_row5_col6" class="data row5 col6" >22</td>
#       <td id="T_5b239_row5_col7" class="data row5 col7" >3</td>
#       <td id="T_5b239_row5_col8" class="data row5 col8" >3</td>
#       <td id="T_5b239_row5_col9" class="data row5 col9" >0</td>
#       <td id="T_5b239_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_5b239_row5_col11" class="data row5 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_5b239_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_5b239_row6_col1" class="data row6 col1" >▲ 1</td>
#       <td id="T_5b239_row6_col2" class="data row6 col2" >Chirag</td>
#       <td id="T_5b239_row6_col3" class="data row6 col3" >999 (0)</td>
#       <td id="T_5b239_row6_col4" class="data row6 col4" >27</td>
#       <td id="T_5b239_row6_col5" class="data row6 col5" >48</td>
#       <td id="T_5b239_row6_col6" class="data row6 col6" >3</td>
#       <td id="T_5b239_row6_col7" class="data row6 col7" >4</td>
#       <td id="T_5b239_row6_col8" class="data row6 col8" >4</td>
#       <td id="T_5b239_row6_col9" class="data row6 col9" >0</td>
#       <td id="T_5b239_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_5b239_row6_col11" class="data row6 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_5b239_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_5b239_row7_col1" class="data row7 col1" >▼ 3</td>
#       <td id="T_5b239_row7_col2" class="data row7 col2" >Ani</td>
#       <td id="T_5b239_row7_col3" class="data row7 col3" >999 (-1)</td>
#       <td id="T_5b239_row7_col4" class="data row7 col4" >358</td>
#       <td id="T_5b239_row7_col5" class="data row7 col5" >48</td>
#       <td id="T_5b239_row7_col6" class="data row7 col6" >3</td>
#       <td id="T_5b239_row7_col7" class="data row7 col7" >8</td>
#       <td id="T_5b239_row7_col8" class="data row7 col8" >7</td>
#       <td id="T_5b239_row7_col9" class="data row7 col9" >5</td>
#       <td id="T_5b239_row7_col10" class="data row7 col10" >0</td>
#       <td id="T_5b239_row7_col11" class="data row7 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_5b239_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_5b239_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_5b239_row8_col2" class="data row8 col2" >Darshan</td>
#       <td id="T_5b239_row8_col3" class="data row8 col3" >997 (0)</td>
#       <td id="T_5b239_row8_col4" class="data row8 col4" >61</td>
#       <td id="T_5b239_row8_col5" class="data row8 col5" >47</td>
#       <td id="T_5b239_row8_col6" class="
#  -----------------------------

# %% [markdown]
# ### Fin!
