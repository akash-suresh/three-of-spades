# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 1
TOURNAMENT_TYPE = TournamentTypes.TINY_CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Tiny Championship #1
# Players participating in this Tiny Championship are : ['Prateek', 'Nats', 'Akash']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 1     Nats    25          39      133.3         5200           64.1
# 0    Akash    22          39      111.5         4350           56.4
# 2  Prateek    20          39      103.5         4035           51.3

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 0    Akash     Nats    12       4          16      143.4           75.0
# 2     Nats  Prateek    10       4          14      148.2           71.4

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Player_z, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 1     Nats           11
# 2    Akash            8
# 0  Prateek            5

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/13 [00:00<?, ?it/s]
#  15%|█▌        | 2/13 [00:00<00:00, 14.45it/s]
#  31%|███       | 4/13 [00:00<00:00, 12.75it/s]
#  46%|████▌     | 6/13 [00:00<00:00, 14.47it/s]
#  62%|██████▏   | 8/13 [00:00<00:00, 14.44it/s]
#  77%|███████▋  | 10/13 [00:00<00:00, 11.22it/s]
#  92%|█████████▏| 12/13 [00:00<00:00, 12.26it/s]
# 100%|██████████| 13/13 [00:01<00:00, 12.74it/s]
# Tiny Championship #1
# <style type="text/css">
# </style>
# <table id="T_1ea0b">
#   <thead>
#     <tr>
#       <th id="T_1ea0b_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_1ea0b_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_1ea0b_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_1ea0b_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_1ea0b_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_1ea0b_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_1ea0b_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ea0b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1ea0b_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_1ea0b_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_1ea0b_row0_col3" class="data row0 col3" >1169 (0)</td>
#       <td id="T_1ea0b_row0_col4" class="data row0 col4" >659</td>
#       <td id="T_1ea0b_row0_col5" class="data row0 col5" >58</td>
#       <td id="T_1ea0b_row0_col6" class="data row0 col6" >12</td>
#     </tr>
#     <tr>
#       <td id="T_1ea0b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_1ea0b_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_1ea0b_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_1ea0b_row1_col3" class="data row1 col3" >1048 (+3)</td>
#       <td id="T_1ea0b_row1_col4" class="data row1 col4" >598</td>
#       <td id="T_1ea0b_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_1ea0b_row1_col6" class="data row1 col6" >9</td>
#     </tr>
#     <tr>
#       <td id="T_1ea0b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_1ea0b_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_1ea0b_row2_col2" class="data row2 col2" >Nats</td>
#       <td id="T_1ea0b_row2_col3" class="data row2 col3" >1025 (+13)</td>
#       <td id="T_1ea0b_row2_col4" class="data row2 col4" >574</td>
#       <td id="T_1ea0b_row2_col5" class="data row2 col5" >50</td>
#       <td id="T_1ea0b_row2_col6" class="data row2 col6" >11</td>
#     </tr>
#     <tr>
#       <td id="T_1ea0b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_1ea0b_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_1ea0b_row3_col2" class="data row3 col2" >Ani</td>
#       <td id="T_1ea0b_row3_col3" class="data row3 col3" >1005 (0)</td>
#       <td id="T_1ea0b_row3_col4" class="data row3 col4" >283</td>
#       <td id="T_1ea0b_row3_col5" class="data row3 col5" >49</td>
#       <td id="T_1ea0b_row3_col6" class="data row3 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_1ea0b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_1ea0b_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_1ea0b_row4_col2" class="data row4 col2" >Shreyas</td>
#       <td id="T_1ea0b_row4_col3" class="data row4 col3" >1000 (0)</td>
#       <td id="T_1ea0b_row4_col4" class="data row4 col4" >61</td>
#       <td id="T_1ea0b_row4_col5" class="data row4 col5" >49</td>
#       <td id="T_1ea0b_row4_col6" class="data row4 col6" >8</td>
#     </tr>
#     <tr>
#       <td id="T_1ea0b_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_1ea0b_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_1ea0b_row5_col2" class="data row5 col2" >Darshan</td>
#       <td id="T_1ea0b_row5_col3" class="data row5 col3" >997 (0)</td>
#       <td id="T_1ea0b_row5_col4" class="data row5 col4" >61</td>
#       <td id="T_1ea0b_row5_col5" class="data row5 col5" >47</td>
#       <td id="T_1ea0b_row5_col6" class="data row5 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_1ea0b_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_1ea0b_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_1ea0b_row6_col2" class="data row6 col2" >Naati</td>
#       <td id="T_1ea0b_row6_col3" class="data row6 col3" >996 (0)</td>
#       <td id="T_1ea0b_row6_col4" class="data row6 col4" >289</td>
#       <td id="T_1ea0b_row6_col5" class="data row6 col5" >49</td>
#       <td id="T_1ea0b_row6_col6" class="data row6 col6" >8</td>
#     </tr>
#     <tr>
#       <td id="T_1ea0b_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_1ea0b_row7_col1" class="data row7 col1" >-</td>
#       <td id="T_1ea0b_row7_col2" class="data row7 col2" >Priya</td>
#       <td id="T_1ea0b_row7_col3" class="data row7 col3" >984 (0)</td>
#       <td id="T_1ea0b_row7_col4" class="data row7 col4" >61</td>
#       <td id="T_1ea0b_row7_col5" class="data row7 col5" >42</td>
#       <td id="T_1ea0b_row7_col6" class="data row7 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_1ea0b_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_1ea0b_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_1ea0b_row8_col2" class="data row8 col2" >Abhi</td>
#       <td id="T_1ea0b_row8_col3" class="data row8 col3" >935 (0)</td>
#       <td id="T_1ea0b_row8_col4" class="data row8 col4" >484</td>
#       <td id="T_1ea0b_row8_col5" class="data row8 col5" >44</td>
#       <td id="T_1ea0b_row8_col6" class="data row8 col6" >7</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
