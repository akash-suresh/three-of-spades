# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 2
TOURNAMENT_TYPE = TournamentTypes.TINY_CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Tiny Championship #2
# Players participating in this Tiny Championship are : ['Skanda', 'Nats', 'Akash']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#    Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 0   Akash    46          76      128.2         9740           60.5
# 1    Nats    42          76      118.9         9035           55.3
# 2  Skanda    36          76      101.3         7700           47.4

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 0    Akash     Nats    21       9          30      145.5           70.0
# 1    Akash   Skanda    13       7          20      137.8           65.0
# 2     Nats   Skanda    14      12          26      113.7           53.8

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
# Empty DataFrame
# Columns: [Player_x, Player_y, Player_z, Wins, Losses, TotalGames, AvgPoints, WinPercentage]
# Index: []

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#    Player  Bid and Won
# 1    Nats           17
# 0  Skanda           12
# 2   Akash           12

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/19 [00:00<?, ?it/s]
#  11%|█         | 2/19 [00:00<00:00, 17.68it/s]
#  21%|██        | 4/19 [00:00<00:01, 11.79it/s]
#  32%|███▏      | 6/19 [00:00<00:00, 14.45it/s]
#  42%|████▏     | 8/19 [00:00<00:00, 15.55it/s]
#  53%|█████▎    | 10/19 [00:00<00:00, 15.08it/s]
#  63%|██████▎   | 12/19 [00:00<00:00, 16.20it/s]
#  74%|███████▎  | 14/19 [00:00<00:00, 15.18it/s]
#  84%|████████▍ | 16/19 [00:01<00:00, 13.28it/s]
# 100%|██████████| 19/19 [00:01<00:00, 14.46it/s]
# 100%|██████████| 19/19 [00:01<00:00, 14.55it/s]
# Tiny Championship #2
# <style type="text/css">
# </style>
# <table id="T_3dbd5">
#   <thead>
#     <tr>
#       <th id="T_3dbd5_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_3dbd5_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_3dbd5_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_3dbd5_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_3dbd5_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_3dbd5_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_3dbd5_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_3dbd5_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_3dbd5_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_3dbd5_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_3dbd5_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_3dbd5_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3dbd5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3dbd5_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_3dbd5_row0_col2" class="data row0 col2" >Akash</td>
#       <td id="T_3dbd5_row0_col3" class="data row0 col3" >1176 (+6)</td>
#       <td id="T_3dbd5_row0_col4" class="data row0 col4" >744</td>
#       <td id="T_3dbd5_row0_col5" class="data row0 col5" >58</td>
#       <td id="T_3dbd5_row0_col6" class="data row0 col6" >12</td>
#       <td id="T_3dbd5_row0_col7" class="data row0 col7" >12</td>
#       <td id="T_3dbd5_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_3dbd5_row0_col9" class="data row0 col9" >18</td>
#       <td id="T_3dbd5_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_3dbd5_row0_col11" class="data row0 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3dbd5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_3dbd5_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_3dbd5_row1_col2" class="data row1 col2" >Prateek</td>
#       <td id="T_3dbd5_row1_col3" class="data row1 col3" >1037 (0)</td>
#       <td id="T_3dbd5_row1_col4" class="data row1 col4" >607</td>
#       <td id="T_3dbd5_row1_col5" class="data row1 col5" >53</td>
#       <td id="T_3dbd5_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_3dbd5_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_3dbd5_row1_col8" class="data row1 col8" >6</td>
#       <td id="T_3dbd5_row1_col9" class="data row1 col9" >5</td>
#       <td id="T_3dbd5_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_3dbd5_row1_col11" class="data row1 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3dbd5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_3dbd5_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_3dbd5_row2_col2" class="data row2 col2" >Nats</td>
#       <td id="T_3dbd5_row2_col3" class="data row2 col3" >1030 (+9)</td>
#       <td id="T_3dbd5_row2_col4" class="data row2 col4" >659</td>
#       <td id="T_3dbd5_row2_col5" class="data row2 col5" >50</td>
#       <td id="T_3dbd5_row2_col6" class="data row2 col6" >12</td>
#       <td id="T_3dbd5_row2_col7" class="data row2 col7" >10</td>
#       <td id="T_3dbd5_row2_col8" class="data row2 col8" >9</td>
#       <td id="T_3dbd5_row2_col9" class="data row2 col9" >15</td>
#       <td id="T_3dbd5_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_3dbd5_row2_col11" class="data row2 col11" >11</td>
#     </tr>
#     <tr>
#       <td id="T_3dbd5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_3dbd5_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_3dbd5_row3_col2" class="data row3 col2" >Ani</td>
#       <td id="T_3dbd5_row3_col3" class="data row3 col3" >1005 (0)</td>
#       <td id="T_3dbd5_row3_col4" class="data row3 col4" >283</td>
#       <td id="T_3dbd5_row3_col5" class="data row3 col5" >49</td>
#       <td id="T_3dbd5_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_3dbd5_row3_col7" class="data row3 col7" >8</td>
#       <td id="T_3dbd5_row3_col8" class="data row3 col8" >6</td>
#       <td id="T_3dbd5_row3_col9" class="data row3 col9" >5</td>
#       <td id="T_3dbd5_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_3dbd5_row3_col11" class="data row3 col11" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3dbd5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_3dbd5_row4_col1" class="data row4 col1" >▲ 1</td>
#       <td id="T_3dbd5_row4_col2" class="data row4 col2" >Skanda</td>
#       <td id="T_3dbd5_row4_col3" class="data row4 col3" >1002 (+2)</td>
#       <td id="T_3dbd5_row4_col4" class="data row4 col4" >76</td>
#       <td id="T_3dbd5_row4_col5" class="data row4 col5" >47</td>
#       <td id="T_3dbd5_row4_col6" class="data row4 col6" >15</td>
#       <td id="T_3dbd5_row4_col7" class="data row4 col7" >5</td>
#       <td id="T_3dbd5_row4_col8" class="data row4 col8" >6</td>
#       <td id="T_3dbd5_row4_col9" class="data row4 col9" >1</td>
#       <td id="T_3dbd5_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_3dbd5_row4_col11" class="data row4 col11" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3dbd5_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_3dbd5_row5_col1" class="data row5 col1" >▼ 1</td>
#       <td id="T_3dbd5_row5_col2" class="data row5 col2" >Shreyas</td>
#       <td id="T_3dbd5_row5_col3" class="data row5 col3" >1000 (0)</td>
#       <td id="T_3dbd5_row5_col4" class="data row5 col4" >61</td>
#       <td id="T_3dbd5_row5_col5" class="data row5 col5" >49</td>
#       <td id="T_3dbd5_row5_col6" class="data row5 col6" >8</td>
#       <td id="T_3dbd5_row5_col7" class="data row5 col7" >4</td>
#       <td id="T_3dbd5_row5_col8" class="data row5 col8" >3</td>
#       <td id="T_3dbd5_row5_col9" class="data row5 col9" >0</td>
#       <td id="T_3dbd5_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_3dbd5_row5_col11" class="data row5 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3dbd5_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_3dbd5_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_3dbd5_row6_col2" class="data row6 col2" >Yandigeri</td>
#       <td id="T_3dbd5_row6_col3" class="data row6 col3" >999 (0)</td>
#       <td id="T_3dbd5_row6_col4" class="data row6 col4" >9</td>
#       <td id="T_3dbd5_row6_col5" class="data row6 col5" >44</td>
#       <td id="T_3dbd5_row6_col6" class="data row6 col6" >22</td>
#       <td id="T_3dbd5_row6_col7" class="data row6 col7" >3</td>
#       <td id="T_3dbd5_row6_col8" class="data row6 col8" >3</td>
#       <td id="T_3dbd5_row6_col9" class="data row6 col9" >0</td>
#       <td id="T_3dbd5_row6_col10" class="data row6 col10" >0</td>
#       <td id="T_3dbd5_row6_col11" class="data row6 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3dbd5_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_3dbd5_row7_col1" class="data row7 col1" >-</td>
#       <td id="T_3dbd5_row7_col2" class="data row7 col2" >Naati</td>
#       <td id="T_3dbd5_row7_col3" class="data row7 col3" >997 (0)</td>
#       <td id="T_3dbd5_row7_col4" class="data row7 col4" >289</td>
#       <td id="T_3dbd5_row7_col5" class="data row7 col5" >49</td>
#       <td id="T_3dbd5_row7_col6" class="data row7 col6" >8</td>
#       <td id="T_3dbd5_row7_col7" class="data row7 col7" >9</td>
#       <td id="T_3dbd5_row7_col8" class="data row7 col8" >6</td>
#       <td id="T_3dbd5_row7_col9" class="data row7 col9" >5</td>
#       <td id="T_3dbd5_row7_col10" class="data row7 col10" >0</td>
#       <td id="T_3dbd5_row7_col11" class="data row7 col11" >7</td>
#     </tr>
#     <tr>
#       <td id="T_3dbd5_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_3dbd5_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_3dbd5_row8_col2" class="data row8 col2" >Darshan</td>
#       <td id="T_3dbd5_row8_col3" class="data row8 col3" >997 (0)</td>
#       <td id="T_3dbd5_row8_col4" class="data row8 col4" >61</td>
#       <td id="T_3dbd5_row8_col5" class="data row8 col5" >47</td>
#       <td id="T_3dbd5_row8_col6" class="data row8 co
#  -----------------------------

# %% [markdown]
# ### Fin!
