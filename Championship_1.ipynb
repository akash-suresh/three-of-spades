# %%
from utils.constants import TournamentTypes
from utils.Tournament import Tournament
from utils.ranking_system import UniversalRatingSystem
from utils.tournament_helper import load_tournaments_from_history

# %% [markdown]
# Enter Tournament Details here

# %%
TOURNEY_NUMBER = 1
TOURNAMENT_TYPE = TournamentTypes.CHAMPIONSHIP
SAVE_IMAGES = False

# %% [markdown]
# ### Reading Data

# %%
tournament = Tournament(TOURNAMENT_TYPE, TOURNEY_NUMBER)
# Out:
# > 3 of Spades Championship #1
# Players participating in this Championship are : ['Akash', 'Abhi', 'Ani', 'Naati', 'Prateek']

# %% [markdown]
# # Part 1 - Crunching player stats

# %%
tournament.getScoreBoard()
# Out:
#     Player  Wins  TotalGames  AvgPoints  TotalPoints  WinPercentage
# 4  Prateek    22          37      220.3         8150           59.5
# 1    Akash    20          37      211.9         7840           54.1
# 3    Naati    20          37      209.5         7750           54.1
# 0     Abhi    21          37      208.4         7710           56.8
# 2      Ani    18          37      181.1         6700           48.6

# %%
tournament.getLeaderboardBarplot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 2 - Seeing performance graph over the tournament

# %%
tournament.getTimeseriesPlot(save_image=SAVE_IMAGES)
tournament.getWinRatioSeriesPlot(save_image=SAVE_IMAGES)

# %% [markdown]
# # Part 3 - Pair-wise stats

# %%
tournament.pairwiseStats
# Out:
#   Player_x Player_y  Wins  Losses  TotalGames  AvgPoints  WinPercentage
# 3     Abhi  Prateek    10       4          14      256.4           71.4
# 2     Abhi    Naati     7       3          10      255.0           70.0
# 6    Akash  Prateek    10       5          15      250.0           66.7
# 0     Abhi    Akash    10       6          16      234.4           62.5
# 9    Naati  Prateek    13       8          21      231.4           61.9
# 5    Akash    Naati     9       6          15      242.7           60.0
# 8      Ani  Prateek    10       7          17      208.2           58.8
# 1     Abhi      Ani     9       7          16      201.2           56.2
# 7      Ani    Naati     7       6          13      202.3           53.8
# 4    Akash      Ani     8       7          15      208.7           53.3

# %% [markdown]
# # Part 4 - Trio stats

# %%
tournament.trioStats
# Out:
#   Player_x Player_y Player_z  Wins  Losses  TotalGames  AvgPoints  \
# 0     Abhi    Akash      Ani     4       1           5      298.0
# 4     Abhi      Ani  Prateek     4       1           5      278.0
# 9      Ani    Naati  Prateek     5       2           7      247.1
# 8    Akash    Naati  Prateek     5       2           7      277.1
# 7    Akash      Ani  Prateek     3       2           5      218.0
#
#    WinPercentage
# 0           80.0
# 4           80.0
# 9           71.4
# 8           71.4
# 7           60.0

# %% [markdown]
# # Part 5 - #games bid and won

# %%
tournament.bidAndWonStats
# Out:
#     Player  Bid and Won
# 3    Naati            5
# 0    Akash            4
# 1     Abhi            3
# 4  Prateek            3
# 2      Ani            1

# %% [markdown]
# # Part 6 - Overall Player Rankings

# %%
universal_rating_system = UniversalRatingSystem()

load_tournaments_from_history(universal_rating_system)

universal_rating_system.showRankingChange(tournament)
# Out:
# Going back in time!
#   0%|          | 0/28 [00:00<?, ?it/s]
#   7%|▋         | 2/28 [00:00<00:01, 18.42it/s]
#  14%|█▍        | 4/28 [00:00<00:01, 15.08it/s]
#  25%|██▌       | 7/28 [00:00<00:01, 17.47it/s]
#  36%|███▌      | 10/28 [00:00<00:01, 15.93it/s]
#  43%|████▎     | 12/28 [00:00<00:00, 16.48it/s]
#  50%|█████     | 14/28 [00:00<00:00, 15.47it/s]
#  57%|█████▋    | 16/28 [00:01<00:00, 15.46it/s]
#  68%|██████▊   | 19/28 [00:01<00:00, 16.40it/s]
#  79%|███████▊  | 22/28 [00:01<00:00, 17.89it/s]
#  86%|████████▌ | 24/28 [00:01<00:00, 16.59it/s]
#  93%|█████████▎| 26/28 [00:01<00:00, 17.08it/s]
# 100%|██████████| 28/28 [00:01<00:00, 16.95it/s]
# Championship #1
# <style type="text/css">
# </style>
# <table id="T_096b8">
#   <thead>
#     <tr>
#       <th id="T_096b8_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_096b8_level0_col1" class="col_heading level0 col1" >Change</th>
#       <th id="T_096b8_level0_col2" class="col_heading level0 col2" >Player</th>
#       <th id="T_096b8_level0_col3" class="col_heading level0 col3" >Rating</th>
#       <th id="T_096b8_level0_col4" class="col_heading level0 col4" >#Games</th>
#       <th id="T_096b8_level0_col5" class="col_heading level0 col5" >Win %</th>
#       <th id="T_096b8_level0_col6" class="col_heading level0 col6" >Bid+Win%</th>
#       <th id="T_096b8_level0_col7" class="col_heading level0 col7" >Win Streak</th>
#       <th id="T_096b8_level0_col8" class="col_heading level0 col8" >Loss Streak</th>
#       <th id="T_096b8_level0_col9" class="col_heading level0 col9" >#Fivples</th>
#       <th id="T_096b8_level0_col10" class="col_heading level0 col10" >#Tenples</th>
#       <th id="T_096b8_level0_col11" class="col_heading level0 col11" >#FiveMottes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_096b8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_096b8_row0_col1" class="data row0 col1" >▲ 4</td>
#       <td id="T_096b8_row0_col2" class="data row0 col2" >Prateek</td>
#       <td id="T_096b8_row0_col3" class="data row0 col3" >1011 (+11)</td>
#       <td id="T_096b8_row0_col4" class="data row0 col4" >37</td>
#       <td id="T_096b8_row0_col5" class="data row0 col5" >59</td>
#       <td id="T_096b8_row0_col6" class="data row0 col6" >8</td>
#       <td id="T_096b8_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_096b8_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_096b8_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_096b8_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_096b8_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_096b8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_096b8_row1_col1" class="data row1 col1" >▼ 1</td>
#       <td id="T_096b8_row1_col2" class="data row1 col2" >Akash</td>
#       <td id="T_096b8_row1_col3" class="data row1 col3" >1008 (+8)</td>
#       <td id="T_096b8_row1_col4" class="data row1 col4" >37</td>
#       <td id="T_096b8_row1_col5" class="data row1 col5" >54</td>
#       <td id="T_096b8_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_096b8_row1_col7" class="data row1 col7" >6</td>
#       <td id="T_096b8_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_096b8_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_096b8_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_096b8_row1_col11" class="data row1 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_096b8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_096b8_row2_col1" class="data row2 col1" >▼ 1</td>
#       <td id="T_096b8_row2_col2" class="data row2 col2" >Abhi</td>
#       <td id="T_096b8_row2_col3" class="data row2 col3" >1007 (+7)</td>
#       <td id="T_096b8_row2_col4" class="data row2 col4" >37</td>
#       <td id="T_096b8_row2_col5" class="data row2 col5" >56</td>
#       <td id="T_096b8_row2_col6" class="data row2 col6" >8</td>
#       <td id="T_096b8_row2_col7" class="data row2 col7" >4</td>
#       <td id="T_096b8_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_096b8_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_096b8_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_096b8_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_096b8_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_096b8_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_096b8_row3_col2" class="data row3 col2" >Naati</td>
#       <td id="T_096b8_row3_col3" class="data row3 col3" >1007 (+7)</td>
#       <td id="T_096b8_row3_col4" class="data row3 col4" >37</td>
#       <td id="T_096b8_row3_col5" class="data row3 col5" >54</td>
#       <td id="T_096b8_row3_col6" class="data row3 col6" >13</td>
#       <td id="T_096b8_row3_col7" class="data row3 col7" >4</td>
#       <td id="T_096b8_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_096b8_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_096b8_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_096b8_row3_col11" class="data row3 col11" >0</td>
#     </tr>
#     <tr>
#       <td id="T_096b8_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_096b8_row4_col1" class="data row4 col1" >▼ 2</td>
#       <td id="T_096b8_row4_col2" class="data row4 col2" >Ani</td>
#       <td id="T_096b8_row4_col3" class="data row4 col3" >997 (-3)</td>
#       <td id="T_096b8_row4_col4" class="data row4 col4" >37</td>
#       <td id="T_096b8_row4_col5" class="data row4 col5" >48</td>
#       <td id="T_096b8_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_096b8_row4_col7" class="data row4 col7" >4</td>
#       <td id="T_096b8_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_096b8_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_096b8_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_096b8_row4_col11" class="data row4 col11" >0</td>
#     </tr>
#   </tbody>
# </table>
#  -----------------------------

# %% [markdown]
# ### Fin!
